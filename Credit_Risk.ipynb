# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# # Project Based Internship<br><br>by Rakamin Academy

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
import xgboost as xgb
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ## Importing Data

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv(r'C:\Users\Ibrahim Erlangga\Downloads\loan_data_2007_2014.csv')
df
# Out:
# C:\Users\Ibrahim Erlangga\AppData\Local\Temp\ipykernel_16132\1601341602.py:3: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\Ibrahim Erlangga\Downloads\loan_data_2007_2014.csv')
#         Unnamed: 0       id  member_id  loan_amnt  funded_amnt  \
# 0                0  1077501    1296599       5000         5000
# 1                1  1077430    1314167       2500         2500
# 2                2  1077175    1313524       2400         2400
# 3                3  1076863    1277178      10000        10000
# 4                4  1075358    1311748       3000         3000
# ...            ...      ...        ...        ...          ...
# 466280      466280  8598660    1440975      18400        18400
# 466281      466281  9684700   11536848      22000        22000
# 466282      466282  9584776   11436914      20700        20700
# 466283      466283  9604874   11457002       2000         2000
# 466284      466284  9199665   11061576      10000        10000
#
#         funded_amnt_inv        term  int_rate  installment grade sub_grade  \
# 0                4975.0   36 months     10.65       162.87     B        B2
# 1                2500.0   60 months     15.27        59.83     C        C4
# 2                2400.0   36 months     15.96        84.33     C        C5
# 3               10000.0   36 months     13.49       339.31     C        C1
# 4                3000.0   60 months     12.69        67.79     B        B5
# ...                 ...         ...       ...          ...   ...       ...
# 466280          18400.0   60 months     14.47       432.64     C        C2
# 466281          22000.0   60 months     19.97       582.50     D        D5
# 466282          20700.0   60 months     16.99       514.34     D        D1
# 466283           2000.0   36 months      7.90        62.59     A        A4
# 466284           9975.0   36 months     19.20       367.58     D        D3
#
#                                     emp_title emp_length home_ownership  \
# 0                                         NaN  10+ years           RENT
# 1                                       Ryder   < 1 year           RENT
# 2                                         NaN  10+ years           RENT
# 3                         AIR RESOURCES BOARD  10+ years           RENT
# 4                    University Medical Group     1 year           RENT
# ...                                       ...        ...            ...
# 466280                     Financial Advisor     4 years       MORTGAGE
# 466281  Chief of Interpretation (Park Ranger)  10+ years       MORTGAGE
# 466282                                 patrol    7 years       MORTGAGE
# 466283                   Server Engineer Lead    3 years            OWN
# 466284                                    NaN  10+ years       MORTGAGE
#
#         annual_inc verification_status issue_d  loan_status pymnt_plan  \
# 0          24000.0            Verified  Dec-11   Fully Paid          n
# 1          30000.0     Source Verified  Dec-11  Charged Off          n
# 2          12252.0        Not Verified  Dec-11   Fully Paid          n
# 3          49200.0     Source Verified  Dec-11   Fully Paid          n
# 4          80000.0     Source Verified  Dec-11      Current          n
# ...            ...                 ...     ...          ...        ...
# 466280    110000.0     Source Verified  Jan-14      Current          n
# 466281     78000.0            Verified  Jan-14  Charged Off          n
# 466282     46000.0            Verified  Jan-14      Current          n
# 466283     83000.0            Verified  Jan-14   Fully Paid          n
# 466284     46000.0            Verified  Jan-14      Current          n
#
#                                                       url  \
# 0       https://www.lendingclub.com/browse/loanDetail....
# 1       https://www.lendingclub.com/browse/loanDetail....
# 2       https://www.lendingclub.com/browse/loanDetail....
# 3       https://www.lendingclub.com/browse/loanDetail....
# 4       https://www.lendingclub.com/browse/loanDetail....
# ...                                                   ...
# 466280  https://www.lendingclub.com/browse/loanDetail....
# 466281  https://www.lendingclub.com/browse/loanDetail....
# 466282  https://www.lendingclub.com/browse/loanDetail....
# 466283  https://www.lendingclub.com/browse/loanDetail....
# 466284  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 0         Borrower added on 12/22/11 > I need to upgra...         credit_card
# 1         Borrower added on 12/22/11 > I plan to use t...                 car
# 2                                                     NaN      small_business
# 3         Borrower added on 12/21/11 > to pay for prop...               other
# 4         Borrower added on 12/21/11 > I plan on combi...               other
# ...                                                   ...                 ...
# 466280                                                NaN  debt_consolidation
# 466281                                                NaN  debt_consolidation
# 466282    Borrower added on 12/06/13 > I am going to c...  debt_consolidation
# 466283                                                NaN         credit_card
# 466284    Borrower added on 12/04/13 > I will like a l...               other
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0                      Computer    860xx         AZ  27.65          0.0
# 1                          bike    309xx         GA   1.00          0.0
# 2          real estate business    606xx         IL   8.72          0.0
# 3                      personel    917xx         CA  20.00          0.0
# 4                      Personal    972xx         OR  17.94          0.0
# ...                         ...      ...        ...    ...          ...
# 466280       Debt consolidation    773xx         TX  19.85          0.0
# 466281       Debt consolidation    377xx         TN  18.45          0.0
# 466282       Debt consolidation    458xx         OH  25.65          0.0
# 466283  Credit card refinancing    913xx         CA   5.39          3.0
# 466284                    Other    950xx         CA  22.78          1.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0                Jan-85             1.0                     NaN
# 1                Apr-99             5.0                     NaN
# 2                Nov-01             2.0                     NaN
# 3                Feb-96             1.0                    35.0
# 4                Jan-96             0.0                    38.0
# ...                 ...             ...                     ...
# 466280           Apr-03             2.0                     NaN
# 466281           Jun-97             5.0                     NaN
# 466282           Dec-01             2.0                    65.0
# 466283           Feb-03             1.0                    13.0
# 466284           Feb-00             0.0                     9.0
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                          NaN       3.0      0.0      13648        83.7
# 1                          NaN       3.0      0.0       1687         9.4
# 2                          NaN       2.0      0.0       2956        98.5
# 3                          NaN      10.0      0.0       5598        21.0
# 4                          NaN      15.0      0.0      27783        53.9
# ...                        ...       ...      ...        ...         ...
# 466280                     NaN      18.0      0.0      23208        77.6
# 466281                   116.0      18.0      1.0      18238        46.3
# 466282                     NaN      18.0      0.0       6688        51.1
# 466283                     NaN      21.0      0.0      11404        21.5
# 466284                     NaN       6.0      0.0      11325        70.8
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0             9.0                   f       0.00           0.00   5861.071414
# 1             4.0                   f       0.00           0.00   1008.710000
# 2            10.0                   f       0.00           0.00   3003.653644
# 3            37.0                   f       0.00           0.00  12226.302210
# 4            38.0                   f     766.90         766.90   3242.170000
# ...           ...                 ...        ...            ...           ...
# 466280       36.0                   w   12574.00       12574.00  10383.360000
# 466281       30.0                   f       0.00           0.00   4677.920000
# 466282       43.0                   f   14428.31       14428.31  12343.980000
# 466283       27.0                   w       0.00           0.00   2126.579838
# 466284       22.0                   f    3984.38        3974.41   8821.620000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0               5831.78          5000.00         861.07                0.00
# 1               1008.71           456.46         435.17                0.00
# 2               3003.65          2400.00         603.65                0.00
# 3              12226.30         10000.00        2209.33               16.97
# 4               3242.17          2233.10        1009.07                0.00
# ...                 ...              ...            ...                 ...
# 466280         10383.36          5826.00        4557.36                0.00
# 466281          4677.92          1837.04        2840.88                0.00
# 466282         12343.98          6271.69        6072.29                0.00
# 466283          2126.58          2000.00         126.58                0.00
# 466284          8799.57          6015.62        2806.00                0.00
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                     0.00       Jan-15           171.62
# 1           117.08                     1.11       Apr-13           119.66
# 2             0.00                     0.00       Jun-14           649.91
# 3             0.00                     0.00       Jan-15           357.48
# 4             0.00                     0.00       Jan-16            67.79
# ...            ...                      ...          ...              ...
# 466280        0.00                     0.00       Jan-16           432.64
# 466281        0.00                     0.00       Dec-14            17.50
# 466282        0.00                     0.00       Jan-16           514.34
# 466283        0.00                     0.00       Dec-14          1500.68
# 466284        0.00                     0.00       Jan-16           367.58
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0               NaN             Jan-16                         0.0
# 1               NaN             Sep-13                         0.0
# 2               NaN             Jan-16                         0.0
# 3               NaN             Jan-15                         0.0
# 4            Feb-16             Jan-16                         0.0
# ...             ...                ...                         ...
# 466280       Feb-16             Jan-16                         0.0
# 466281          NaN             Jan-16                         0.0
# 466282       Feb-16             Dec-15                         0.0
# 466283          NaN             Apr-15                         0.0
# 466284       Feb-16             Jan-16                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 0                               NaN            1       INDIVIDUAL
# 1                               NaN            1       INDIVIDUAL
# 2                               NaN            1       INDIVIDUAL
# 3                               NaN            1       INDIVIDUAL
# 4                               NaN            1       INDIVIDUAL
# ...                             ...          ...              ...
# 466280                          NaN            1       INDIVIDUAL
# 466281                          NaN            1       INDIVIDUAL
# 466282                          NaN            1       INDIVIDUAL
# 466283                          NaN            1       INDIVIDUAL
# 466284                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint  verification_status_joint  \
# 0                    NaN        NaN                        NaN
# 1                    NaN        NaN                        NaN
# 2                    NaN        NaN                        NaN
# 3                    NaN        NaN                        NaN
# 4                    NaN        NaN                        NaN
# ...                  ...        ...                        ...
# 466280               NaN        NaN                        NaN
# 466281               NaN        NaN                        NaN
# 466282               NaN        NaN                        NaN
# 466283               NaN        NaN                        NaN
# 466284               NaN        NaN                        NaN
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 0                  0.0           NaN          NaN          NaN         NaN
# 1                  0.0           NaN          NaN          NaN         NaN
# 2                  0.0           NaN          NaN          NaN         NaN
# 3                  0.0           NaN          NaN          NaN         NaN
# 4                  0.0           NaN          NaN          NaN         NaN
# ...                ...           ...          ...          ...         ...
# 466280             0.0           0.0     294998.0          NaN         NaN
# 466281             0.0           0.0     221830.0          NaN         NaN
# 466282             0.0           0.0      73598.0          NaN         NaN
# 466283             0.0           0.0     591610.0          NaN         NaN
# 466284             0.0           0.0      57477.0          NaN         NaN
#
#         open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0               NaN          NaN                 NaN           NaN      NaN
# 1               NaN          NaN                 NaN           NaN      NaN
# 2               NaN          NaN                 NaN           NaN      NaN
# 3               NaN          NaN                 NaN           NaN      NaN
# 4               NaN          NaN                 NaN           NaN      NaN
# ...             ...          ...                 ...           ...      ...
# 466280          NaN          NaN                 NaN           NaN      NaN
# 466281          NaN          NaN                 NaN           NaN      NaN
# 466282          NaN          NaN                 NaN           NaN      NaN
# 466283          NaN          NaN                 NaN           NaN      NaN
# 466284          NaN          NaN                 NaN           NaN      NaN
#
#         open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 0               NaN          NaN         NaN       NaN               NaN
# 1               NaN          NaN         NaN       NaN               NaN
# 2               NaN          NaN         NaN       NaN               NaN
# 3               NaN          NaN         NaN       NaN               NaN
# 4               NaN          NaN         NaN       NaN               NaN
# ...             ...          ...         ...       ...               ...
# 466280          NaN          NaN         NaN       NaN           29900.0
# 466281          NaN          NaN         NaN       NaN           39400.0
# 466282          NaN          NaN         NaN       NaN           13100.0
# 466283          NaN          NaN         NaN       NaN           53100.0
# 466284          NaN          NaN         NaN       NaN           16000.0
#
#         inq_fi  total_cu_tl  inq_last_12m
# 0          NaN          NaN           NaN
# 1          NaN          NaN           NaN
# 2          NaN          NaN           NaN
# 3          NaN          NaN           NaN
# 4          NaN          NaN           NaN
# ...        ...          ...           ...
# 466280     NaN          NaN           NaN
# 466281     NaN          NaN           NaN
# 466282     NaN          NaN           NaN
# 466283     NaN          NaN           NaN
# 466284     NaN          NaN           NaN
#
# [466285 rows x 75 columns]

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ## Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  object
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  object
#  10  sub_grade                    466285 non-null  object
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  object
#  13  home_ownership               466285 non-null  object
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  object
#  16  issue_d                      466285 non-null  object
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  object
#  19  url                          466285 non-null  object
#  20  desc                         125981 non-null  object
#  21  purpose                      466285 non-null  object
#  22  title                        466264 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  object
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  object
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  object
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  object
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  object
#  49  last_credit_pull_d           466243 non-null  object
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7), object(22)
# memory usage: 266.8+ MB

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Complete Coloumns

# %%
kolom_lengkap = [kolom for kolom in df.columns if df[kolom].notna().all()]
kolom_lengkap
# Out:
# ['Unnamed: 0',
#  'id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'home_ownership',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'purpose',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'revol_bal',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'policy_code',
#  'application_type']

# %%
for nama_kolom in kolom_lengkap:
    print(f"Kolom {nama_kolom} berisi {df[nama_kolom].count()} data dengan tipe data {df[nama_kolom].dtype}")

print()
print(f"Total dari kolom lengkap sebanyak {len(kolom_lengkap)} kolom")
# Out:
# Kolom Unnamed: 0 berisi 466285 data dengan tipe data int64
# Kolom id berisi 466285 data dengan tipe data int64
# Kolom member_id berisi 466285 data dengan tipe data int64
# Kolom loan_amnt berisi 466285 data dengan tipe data int64
# Kolom funded_amnt berisi 466285 data dengan tipe data int64
# Kolom funded_amnt_inv berisi 466285 data dengan tipe data float64
# Kolom term berisi 466285 data dengan tipe data object
# Kolom int_rate berisi 466285 data dengan tipe data float64
# Kolom installment berisi 466285 data dengan tipe data float64
# Kolom grade berisi 466285 data dengan tipe data object
# Kolom sub_grade berisi 466285 data dengan tipe data object
# Kolom home_ownership berisi 466285 data dengan tipe data object
# Kolom verification_status berisi 466285 data dengan tipe data object
# Kolom issue_d berisi 466285 data dengan tipe data object
# Kolom loan_status berisi 466285 data dengan tipe data object
# Kolom pymnt_plan berisi 466285 data dengan tipe data object
# Kolom url berisi 466285 data dengan tipe data object
# Kolom purpose berisi 466285 data dengan tipe data object
# Kolom zip_code berisi 466285 data dengan tipe data object
# Kolom addr_state berisi 466285 data dengan tipe data object
# Kolom dti berisi 466285 data dengan tipe data float64
# Kolom revol_bal berisi 466285 data dengan tipe data int64
# Kolom initial_list_status berisi 466285 data dengan tipe data object
# Kolom out_prncp berisi 466285 data dengan tipe data float64
# Kolom out_prncp_inv berisi 466285 data dengan tipe data float64
# Kolom total_pymnt berisi 466285 data dengan tipe data float64
# Kolom total_pymnt_inv berisi 466285 data dengan tipe data float64
# Kolom total_rec_prncp berisi 466285 data dengan tipe data float64
# Kolom total_rec_int berisi 466285 data dengan tipe data float64
# Kolom total_rec_late_fee berisi 466285 data dengan tipe data float64
# Kolom recoveries berisi 466285 data dengan tipe data float64
# Kolom collection_recovery_fee berisi 466285 data dengan tipe data float64
# Kolom last_pymnt_amnt berisi 466285 data dengan tipe data float64
# Kolom policy_code berisi 466285 data dengan tipe data int64
# Kolom application_type berisi 466285 data dengan tipe data object
#
# Total dari kolom lengkap sebanyak 35 kolom

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Partial Missing Value

# %%
# partial missing value feature
kolom_kolom = []

for kolom in df.columns:
    if df[kolom].count() != 0:
        if df[kolom].count() < df.shape[0]:
            kolom_kolom.append(kolom)

kolom_kolom
# Out:
# ['emp_title',
#  'emp_length',
#  'annual_inc',
#  'desc',
#  'title',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_util',
#  'total_acc',
#  'last_pymnt_d',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'total_rev_hi_lim']

# %%
for nama_kolom in kolom_kolom:
    print(f"Kolom {nama_kolom} berisi {df[nama_kolom].count()} data dengan tipe data {df[nama_kolom].dtype}")

print()
print(f"Total dari kolom parsial sebanyak {len(kolom_kolom)} kolom")
# Out:
# Kolom emp_title berisi 438697 data dengan tipe data object
# Kolom emp_length berisi 445277 data dengan tipe data object
# Kolom annual_inc berisi 466281 data dengan tipe data float64
# Kolom desc berisi 125981 data dengan tipe data object
# Kolom title berisi 466264 data dengan tipe data object
# Kolom delinq_2yrs berisi 466256 data dengan tipe data float64
# Kolom earliest_cr_line berisi 466256 data dengan tipe data object
# Kolom inq_last_6mths berisi 466256 data dengan tipe data float64
# Kolom mths_since_last_delinq berisi 215934 data dengan tipe data float64
# Kolom mths_since_last_record berisi 62638 data dengan tipe data float64
# Kolom open_acc berisi 466256 data dengan tipe data float64
# Kolom pub_rec berisi 466256 data dengan tipe data float64
# Kolom revol_util berisi 465945 data dengan tipe data float64
# Kolom total_acc berisi 466256 data dengan tipe data float64
# Kolom last_pymnt_d berisi 465909 data dengan tipe data object
# Kolom next_pymnt_d berisi 239071 data dengan tipe data object
# Kolom last_credit_pull_d berisi 466243 data dengan tipe data object
# Kolom collections_12_mths_ex_med berisi 466140 data dengan tipe data float64
# Kolom mths_since_last_major_derog berisi 98974 data dengan tipe data float64
# Kolom acc_now_delinq berisi 466256 data dengan tipe data float64
# Kolom tot_coll_amt berisi 396009 data dengan tipe data float64
# Kolom tot_cur_bal berisi 396009 data dengan tipe data float64
# Kolom total_rev_hi_lim berisi 396009 data dengan tipe data float64
#
# Total dari kolom parsial sebanyak 23 kolom

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Total Missing Value

# %%
# total missing value feature
kolom_kosong = []

for kolom in df.columns:
    if df[kolom].count() == 0:
        kolom_kosong.append(kolom)

kolom_kosong
# Out:
# ['annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m']

# %%
for nama_kolom in kolom_kosong:
    print(f"Kolom {nama_kolom} berisi {df[nama_kolom].count()} data dengan tipe data {df[nama_kolom].dtype}")

print()
print(f"Total dari kolom parsial sebanyak {len(kolom_kosong)} kolom")
# Out:
# Kolom annual_inc_joint berisi 0 data dengan tipe data float64
# Kolom dti_joint berisi 0 data dengan tipe data float64
# Kolom verification_status_joint berisi 0 data dengan tipe data float64
# Kolom open_acc_6m berisi 0 data dengan tipe data float64
# Kolom open_il_6m berisi 0 data dengan tipe data float64
# Kolom open_il_12m berisi 0 data dengan tipe data float64
# Kolom open_il_24m berisi 0 data dengan tipe data float64
# Kolom mths_since_rcnt_il berisi 0 data dengan tipe data float64
# Kolom total_bal_il berisi 0 data dengan tipe data float64
# Kolom il_util berisi 0 data dengan tipe data float64
# Kolom open_rv_12m berisi 0 data dengan tipe data float64
# Kolom open_rv_24m berisi 0 data dengan tipe data float64
# Kolom max_bal_bc berisi 0 data dengan tipe data float64
# Kolom all_util berisi 0 data dengan tipe data float64
# Kolom inq_fi berisi 0 data dengan tipe data float64
# Kolom total_cu_tl berisi 0 data dengan tipe data float64
# Kolom inq_last_12m berisi 0 data dengan tipe data float64
#
# Total dari kolom parsial sebanyak 17 kolom

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Pecentage Missing Value of Partial

# %%
def get_data_info(df:pd.DataFrame):
    list_item = []
    
    for col in df.columns:
        if (df[col].count() > 0) and (df[col].count() < df.shape[0]):
            list_item.append([col, df[col].dtype, df[col].isna().sum(), round(df[col].isna().sum()/df.shape[0], 2), df[col].nunique(), df[col].unique()[:4]])
    
    desc_df = pd.DataFrame(data=list_item, columns=['Feature', 'Data Type', 'Total Null in Feature', 'Null Percentage', 'Total Unique Element', 'Unique Sample'])
    return desc_df

# %%
get_data_info(df)
# Out:
#                         Feature Data Type  Total Null in Feature  \
# 0                     emp_title    object                  27588
# 1                    emp_length    object                  21008
# 2                    annual_inc   float64                      4
# 3                          desc    object                 340304
# 4                         title    object                     21
# 5                   delinq_2yrs   float64                     29
# 6              earliest_cr_line    object                     29
# 7                inq_last_6mths   float64                     29
# 8        mths_since_last_delinq   float64                 250351
# 9        mths_since_last_record   float64                 403647
# 10                     open_acc   float64                     29
# 11                      pub_rec   float64                     29
# 12                   revol_util   float64                    340
# 13                    total_acc   float64                     29
# 14                 last_pymnt_d    object                    376
# 15                 next_pymnt_d    object                 227214
# 16           last_credit_pull_d    object                     42
# 17   collections_12_mths_ex_med   float64                    145
# 18  mths_since_last_major_derog   float64                 367311
# 19               acc_now_delinq   float64                     29
# 20                 tot_coll_amt   float64                  70276
# 21                  tot_cur_bal   float64                  70276
# 22             total_rev_hi_lim   float64                  70276
#
#     Null Percentage  Total Unique Element  \
# 0              0.06                205475
# 1              0.05                    11
# 2              0.00                 31901
# 3              0.73                124435
# 4              0.00                 63098
# 5              0.00                    24
# 6              0.00                   664
# 7              0.00                    28
# 8              0.54                   145
# 9              0.87                   123
# 10             0.00                    62
# 11             0.00                    26
# 12             0.00                  1269
# 13             0.00                   112
# 14             0.00                    98
# 15             0.49                   100
# 16             0.00                   103
# 17             0.00                     9
# 18             0.79                   162
# 19             0.00                     6
# 20             0.15                  6321
# 21             0.15                220690
# 22             0.15                 14612
#
#                                         Unique Sample
# 0   [nan, Ryder, AIR RESOURCES BOARD, University M...
# 1              [10+ years, < 1 year, 1 year, 3 years]
# 2                [24000.0, 30000.0, 12252.0, 49200.0]
# 3   [  Borrower added on 12/22/11 > I need to upgr...
# 4    [Computer, bike, real estate business, personel]
# 5                                [0.0, 2.0, 3.0, 1.0]
# 6                    [Jan-85, Apr-99, Nov-01, Feb-96]
# 7                                [1.0, 5.0, 2.0, 0.0]
# 8                             [nan, 35.0, 38.0, 61.0]
# 9                           [nan, 113.0, 105.0, 97.0]
# 10                             [3.0, 2.0, 10.0, 15.0]
# 11                               [0.0, 1.0, 2.0, 3.0]
# 12                            [83.7, 9.4, 98.5, 21.0]
# 13                             [9.0, 4.0, 10.0, 37.0]
# 14                   [Jan-15, Apr-13, Jun-14, Jan-16]
# 15                      [nan, Feb-16, Jan-16, Sep-13]
# 16                   [Jan-16, Sep-13, Jan-15, Sep-15]
# 17                               [0.0, nan, 1.0, 2.0]
# 18                            [nan, 53.0, 34.0, 54.0]
# 19                               [0.0, 1.0, nan, 2.0]
# 20                        [nan, 0.0, 15386.0, 1514.0]
# 21                 [nan, 114834.0, 14123.0, 267646.0]
# 22                   [nan, 59900.0, 15100.0, 61100.0]

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ## Data Cleaning

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Data Copy

# %%
df_copy = df.copy()
df_copy
# Out:
#         Unnamed: 0       id  member_id  loan_amnt  funded_amnt  \
# 0                0  1077501    1296599       5000         5000
# 1                1  1077430    1314167       2500         2500
# 2                2  1077175    1313524       2400         2400
# 3                3  1076863    1277178      10000        10000
# 4                4  1075358    1311748       3000         3000
# ...            ...      ...        ...        ...          ...
# 466280      466280  8598660    1440975      18400        18400
# 466281      466281  9684700   11536848      22000        22000
# 466282      466282  9584776   11436914      20700        20700
# 466283      466283  9604874   11457002       2000         2000
# 466284      466284  9199665   11061576      10000        10000
#
#         funded_amnt_inv        term  int_rate  installment grade sub_grade  \
# 0                4975.0   36 months     10.65       162.87     B        B2
# 1                2500.0   60 months     15.27        59.83     C        C4
# 2                2400.0   36 months     15.96        84.33     C        C5
# 3               10000.0   36 months     13.49       339.31     C        C1
# 4                3000.0   60 months     12.69        67.79     B        B5
# ...                 ...         ...       ...          ...   ...       ...
# 466280          18400.0   60 months     14.47       432.64     C        C2
# 466281          22000.0   60 months     19.97       582.50     D        D5
# 466282          20700.0   60 months     16.99       514.34     D        D1
# 466283           2000.0   36 months      7.90        62.59     A        A4
# 466284           9975.0   36 months     19.20       367.58     D        D3
#
#                                     emp_title emp_length home_ownership  \
# 0                                         NaN  10+ years           RENT
# 1                                       Ryder   < 1 year           RENT
# 2                                         NaN  10+ years           RENT
# 3                         AIR RESOURCES BOARD  10+ years           RENT
# 4                    University Medical Group     1 year           RENT
# ...                                       ...        ...            ...
# 466280                     Financial Advisor     4 years       MORTGAGE
# 466281  Chief of Interpretation (Park Ranger)  10+ years       MORTGAGE
# 466282                                 patrol    7 years       MORTGAGE
# 466283                   Server Engineer Lead    3 years            OWN
# 466284                                    NaN  10+ years       MORTGAGE
#
#         annual_inc verification_status issue_d  loan_status pymnt_plan  \
# 0          24000.0            Verified  Dec-11   Fully Paid          n
# 1          30000.0     Source Verified  Dec-11  Charged Off          n
# 2          12252.0        Not Verified  Dec-11   Fully Paid          n
# 3          49200.0     Source Verified  Dec-11   Fully Paid          n
# 4          80000.0     Source Verified  Dec-11      Current          n
# ...            ...                 ...     ...          ...        ...
# 466280    110000.0     Source Verified  Jan-14      Current          n
# 466281     78000.0            Verified  Jan-14  Charged Off          n
# 466282     46000.0            Verified  Jan-14      Current          n
# 466283     83000.0            Verified  Jan-14   Fully Paid          n
# 466284     46000.0            Verified  Jan-14      Current          n
#
#                                                       url  \
# 0       https://www.lendingclub.com/browse/loanDetail....
# 1       https://www.lendingclub.com/browse/loanDetail....
# 2       https://www.lendingclub.com/browse/loanDetail....
# 3       https://www.lendingclub.com/browse/loanDetail....
# 4       https://www.lendingclub.com/browse/loanDetail....
# ...                                                   ...
# 466280  https://www.lendingclub.com/browse/loanDetail....
# 466281  https://www.lendingclub.com/browse/loanDetail....
# 466282  https://www.lendingclub.com/browse/loanDetail....
# 466283  https://www.lendingclub.com/browse/loanDetail....
# 466284  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 0         Borrower added on 12/22/11 > I need to upgra...         credit_card
# 1         Borrower added on 12/22/11 > I plan to use t...                 car
# 2                                                     NaN      small_business
# 3         Borrower added on 12/21/11 > to pay for prop...               other
# 4         Borrower added on 12/21/11 > I plan on combi...               other
# ...                                                   ...                 ...
# 466280                                                NaN  debt_consolidation
# 466281                                                NaN  debt_consolidation
# 466282    Borrower added on 12/06/13 > I am going to c...  debt_consolidation
# 466283                                                NaN         credit_card
# 466284    Borrower added on 12/04/13 > I will like a l...               other
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0                      Computer    860xx         AZ  27.65          0.0
# 1                          bike    309xx         GA   1.00          0.0
# 2          real estate business    606xx         IL   8.72          0.0
# 3                      personel    917xx         CA  20.00          0.0
# 4                      Personal    972xx         OR  17.94          0.0
# ...                         ...      ...        ...    ...          ...
# 466280       Debt consolidation    773xx         TX  19.85          0.0
# 466281       Debt consolidation    377xx         TN  18.45          0.0
# 466282       Debt consolidation    458xx         OH  25.65          0.0
# 466283  Credit card refinancing    913xx         CA   5.39          3.0
# 466284                    Other    950xx         CA  22.78          1.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0                Jan-85             1.0                     NaN
# 1                Apr-99             5.0                     NaN
# 2                Nov-01             2.0                     NaN
# 3                Feb-96             1.0                    35.0
# 4                Jan-96             0.0                    38.0
# ...                 ...             ...                     ...
# 466280           Apr-03             2.0                     NaN
# 466281           Jun-97             5.0                     NaN
# 466282           Dec-01             2.0                    65.0
# 466283           Feb-03             1.0                    13.0
# 466284           Feb-00             0.0                     9.0
#
#         mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 0                          NaN       3.0      0.0      13648        83.7
# 1                          NaN       3.0      0.0       1687         9.4
# 2                          NaN       2.0      0.0       2956        98.5
# 3                          NaN      10.0      0.0       5598        21.0
# 4                          NaN      15.0      0.0      27783        53.9
# ...                        ...       ...      ...        ...         ...
# 466280                     NaN      18.0      0.0      23208        77.6
# 466281                   116.0      18.0      1.0      18238        46.3
# 466282                     NaN      18.0      0.0       6688        51.1
# 466283                     NaN      21.0      0.0      11404        21.5
# 466284                     NaN       6.0      0.0      11325        70.8
#
#         total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0             9.0                   f       0.00           0.00   5861.071414
# 1             4.0                   f       0.00           0.00   1008.710000
# 2            10.0                   f       0.00           0.00   3003.653644
# 3            37.0                   f       0.00           0.00  12226.302210
# 4            38.0                   f     766.90         766.90   3242.170000
# ...           ...                 ...        ...            ...           ...
# 466280       36.0                   w   12574.00       12574.00  10383.360000
# 466281       30.0                   f       0.00           0.00   4677.920000
# 466282       43.0                   f   14428.31       14428.31  12343.980000
# 466283       27.0                   w       0.00           0.00   2126.579838
# 466284       22.0                   f    3984.38        3974.41   8821.620000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0               5831.78          5000.00         861.07                0.00
# 1               1008.71           456.46         435.17                0.00
# 2               3003.65          2400.00         603.65                0.00
# 3              12226.30         10000.00        2209.33               16.97
# 4               3242.17          2233.10        1009.07                0.00
# ...                 ...              ...            ...                 ...
# 466280         10383.36          5826.00        4557.36                0.00
# 466281          4677.92          1837.04        2840.88                0.00
# 466282         12343.98          6271.69        6072.29                0.00
# 466283          2126.58          2000.00         126.58                0.00
# 466284          8799.57          6015.62        2806.00                0.00
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                     0.00       Jan-15           171.62
# 1           117.08                     1.11       Apr-13           119.66
# 2             0.00                     0.00       Jun-14           649.91
# 3             0.00                     0.00       Jan-15           357.48
# 4             0.00                     0.00       Jan-16            67.79
# ...            ...                      ...          ...              ...
# 466280        0.00                     0.00       Jan-16           432.64
# 466281        0.00                     0.00       Dec-14            17.50
# 466282        0.00                     0.00       Jan-16           514.34
# 466283        0.00                     0.00       Dec-14          1500.68
# 466284        0.00                     0.00       Jan-16           367.58
#
#        next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0               NaN             Jan-16                         0.0
# 1               NaN             Sep-13                         0.0
# 2               NaN             Jan-16                         0.0
# 3               NaN             Jan-15                         0.0
# 4            Feb-16             Jan-16                         0.0
# ...             ...                ...                         ...
# 466280       Feb-16             Jan-16                         0.0
# 466281          NaN             Jan-16                         0.0
# 466282       Feb-16             Dec-15                         0.0
# 466283          NaN             Apr-15                         0.0
# 466284       Feb-16             Jan-16                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 0                               NaN            1       INDIVIDUAL
# 1                               NaN            1       INDIVIDUAL
# 2                               NaN            1       INDIVIDUAL
# 3                               NaN            1       INDIVIDUAL
# 4                               NaN            1       INDIVIDUAL
# ...                             ...          ...              ...
# 466280                          NaN            1       INDIVIDUAL
# 466281                          NaN            1       INDIVIDUAL
# 466282                          NaN            1       INDIVIDUAL
# 466283                          NaN            1       INDIVIDUAL
# 466284                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint  verification_status_joint  \
# 0                    NaN        NaN                        NaN
# 1                    NaN        NaN                        NaN
# 2                    NaN        NaN                        NaN
# 3                    NaN        NaN                        NaN
# 4                    NaN        NaN                        NaN
# ...                  ...        ...                        ...
# 466280               NaN        NaN                        NaN
# 466281               NaN        NaN                        NaN
# 466282               NaN        NaN                        NaN
# 466283               NaN        NaN                        NaN
# 466284               NaN        NaN                        NaN
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# 0                  0.0           NaN          NaN          NaN         NaN
# 1                  0.0           NaN          NaN          NaN         NaN
# 2                  0.0           NaN          NaN          NaN         NaN
# 3                  0.0           NaN          NaN          NaN         NaN
# 4                  0.0           NaN          NaN          NaN         NaN
# ...                ...           ...          ...          ...         ...
# 466280             0.0           0.0     294998.0          NaN         NaN
# 466281             0.0           0.0     221830.0          NaN         NaN
# 466282             0.0           0.0      73598.0          NaN         NaN
# 466283             0.0           0.0     591610.0          NaN         NaN
# 466284             0.0           0.0      57477.0          NaN         NaN
#
#         open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0               NaN          NaN                 NaN           NaN      NaN
# 1               NaN          NaN                 NaN           NaN      NaN
# 2               NaN          NaN                 NaN           NaN      NaN
# 3               NaN          NaN                 NaN           NaN      NaN
# 4               NaN          NaN                 NaN           NaN      NaN
# ...             ...          ...                 ...           ...      ...
# 466280          NaN          NaN                 NaN           NaN      NaN
# 466281          NaN          NaN                 NaN           NaN      NaN
# 466282          NaN          NaN                 NaN           NaN      NaN
# 466283          NaN          NaN                 NaN           NaN      NaN
# 466284          NaN          NaN                 NaN           NaN      NaN
#
#         open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 0               NaN          NaN         NaN       NaN               NaN
# 1               NaN          NaN         NaN       NaN               NaN
# 2               NaN          NaN         NaN       NaN               NaN
# 3               NaN          NaN         NaN       NaN               NaN
# 4               NaN          NaN         NaN       NaN               NaN
# ...             ...          ...         ...       ...               ...
# 466280          NaN          NaN         NaN       NaN           29900.0
# 466281          NaN          NaN         NaN       NaN           39400.0
# 466282          NaN          NaN         NaN       NaN           13100.0
# 466283          NaN          NaN         NaN       NaN           53100.0
# 466284          NaN          NaN         NaN       NaN           16000.0
#
#         inq_fi  total_cu_tl  inq_last_12m
# 0          NaN          NaN           NaN
# 1          NaN          NaN           NaN
# 2          NaN          NaN           NaN
# 3          NaN          NaN           NaN
# 4          NaN          NaN           NaN
# ...        ...          ...           ...
# 466280     NaN          NaN           NaN
# 466281     NaN          NaN           NaN
# 466282     NaN          NaN           NaN
# 466283     NaN          NaN           NaN
# 466284     NaN          NaN           NaN
#
# [466285 rows x 75 columns]

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Object to Datetime
#
# Beberapa kolom/feature yang merupakan tipe data `datetime` masih bertipe data object yang mungkin hanya diklasifikasikan sebagai string. Fungsi `pd.Datetime()` akan mengubah fitur-fitur dari kolom ini sebagai `datetime`.

# %%
supposed_datetime = ["issue_d", "earliest_cr_line", "last_pymnt_d", "next_pymnt_d", "last_credit_pull_d"]

for col_date in supposed_datetime:
    print(df_copy[col_date])
    print()
# Out:
# 0         Dec-11
# 1         Dec-11
# 2         Dec-11
# 3         Dec-11
# 4         Dec-11
#            ...
# 466280    Jan-14
# 466281    Jan-14
# 466282    Jan-14
# 466283    Jan-14
# 466284    Jan-14
# Name: issue_d, Length: 466285, dtype: object
#
# 0         Jan-85
# 1         Apr-99
# 2         Nov-01
# 3         Feb-96
# 4         Jan-96
#            ...
# 466280    Apr-03
# 466281    Jun-97
# 466282    Dec-01
# 466283    Feb-03
# 466284    Feb-00
# Name: earliest_cr_line, Length: 466285, dtype: object
#
# 0         Jan-15
# 1         Apr-13
# 2         Jun-14
# 3         Jan-15
# 4         Jan-16
#            ...
# 466280    Jan-16
# 466281    Dec-14
# 466282    Jan-16
# 466283    Dec-14
# 466284    Jan-16
# Name: last_pymnt_d, Length: 466285, dtype: object
#
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4         Feb-16
#            ...
# 466280    Feb-16
# 466281       NaN
# 466282    Feb-16
# 466283       NaN
# 466284    Feb-16
# Name: next_pymnt_d, Length: 466285, dtype: object
#
# 0         Jan-16
# 1         Sep-13
# 2         Jan-16
# 3         Jan-15
# 4         Jan-16
#            ...
# 466280    Jan-16
# 466281    Jan-16
# 466282    Dec-15
# 466283    Apr-15
# 466284    Jan-16
# Name: last_credit_pull_d, Length: 466285, dtype: object

# %%
for col_date in supposed_datetime:
    # df_copy[col_date] = pd.to_datetime(df_copy[col_date])
    # dilihat bentukan tanggal string-nya terlebih dahulu
    # baru ubah ke datetime
    df_copy[col_date] = pd.to_datetime(df_copy[col_date], format='%b-%y')

df_copy[["issue_d", "earliest_cr_line", "last_pymnt_d", "next_pymnt_d", "last_credit_pull_d"]]
# Out:
#           issue_d earliest_cr_line last_pymnt_d next_pymnt_d  \
# 0      2011-12-01       1985-01-01   2015-01-01          NaT
# 1      2011-12-01       1999-04-01   2013-04-01          NaT
# 2      2011-12-01       2001-11-01   2014-06-01          NaT
# 3      2011-12-01       1996-02-01   2015-01-01          NaT
# 4      2011-12-01       1996-01-01   2016-01-01   2016-02-01
# ...           ...              ...          ...          ...
# 466280 2014-01-01       2003-04-01   2016-01-01   2016-02-01
# 466281 2014-01-01       1997-06-01   2014-12-01          NaT
# 466282 2014-01-01       2001-12-01   2016-01-01   2016-02-01
# 466283 2014-01-01       2003-02-01   2014-12-01          NaT
# 466284 2014-01-01       2000-02-01   2016-01-01   2016-02-01
#
#        last_credit_pull_d
# 0              2016-01-01
# 1              2013-09-01
# 2              2016-01-01
# 3              2015-01-01
# 4              2016-01-01
# ...                   ...
# 466280         2016-01-01
# 466281         2016-01-01
# 466282         2015-12-01
# 466283         2015-04-01
# 466284         2016-01-01
#
# [466285 rows x 5 columns]

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# ### Object to Category
#
# Fitur dari data yang bertipe data object, ada yang sebenarnya bertipe data kategori. Tipe kategorinya bisa sebagai nominal dan ordinal. Berikut adalah fitur-fitur yang bertipe objek.

# %%
object_col = []

for kolom in df_copy.columns:
    if df_copy[kolom].dtype == "object":
        object_col.append(kolom)

object_col
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'verification_status',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'initial_list_status',
#  'application_type']

# %%
df_copy[['term',
 'grade',
 'sub_grade',
 'emp_title',
 'emp_length',
 'home_ownership',
 'verification_status',
 'loan_status',
 'pymnt_plan',
 'url',
 'desc',
 'purpose',
 'title',
 'zip_code',
 'addr_state',
 'initial_list_status',
 'application_type']]
# Out:
#               term grade sub_grade                              emp_title  \
# 0        36 months     B        B2                                    NaN
# 1        60 months     C        C4                                  Ryder
# 2        36 months     C        C5                                    NaN
# 3        36 months     C        C1                    AIR RESOURCES BOARD
# 4        60 months     B        B5               University Medical Group
# ...            ...   ...       ...                                    ...
# 466280   60 months     C        C2                     Financial Advisor
# 466281   60 months     D        D5  Chief of Interpretation (Park Ranger)
# 466282   60 months     D        D1                                 patrol
# 466283   36 months     A        A4                   Server Engineer Lead
# 466284   36 months     D        D3                                    NaN
#
#        emp_length home_ownership verification_status  loan_status pymnt_plan  \
# 0       10+ years           RENT            Verified   Fully Paid          n
# 1        < 1 year           RENT     Source Verified  Charged Off          n
# 2       10+ years           RENT        Not Verified   Fully Paid          n
# 3       10+ years           RENT     Source Verified   Fully Paid          n
# 4          1 year           RENT     Source Verified      Current          n
# ...           ...            ...                 ...          ...        ...
# 466280    4 years       MORTGAGE     Source Verified      Current          n
# 466281  10+ years       MORTGAGE            Verified  Charged Off          n
# 466282    7 years       MORTGAGE            Verified      Current          n
# 466283    3 years            OWN            Verified   Fully Paid          n
# 466284  10+ years       MORTGAGE            Verified      Current          n
#
#                                                       url  \
# 0       https://www.lendingclub.com/browse/loanDetail....
# 1       https://www.lendingclub.com/browse/loanDetail....
# 2       https://www.lendingclub.com/browse/loanDetail....
# 3       https://www.lendingclub.com/browse/loanDetail....
# 4       https://www.lendingclub.com/browse/loanDetail....
# ...                                                   ...
# 466280  https://www.lendingclub.com/browse/loanDetail....
# 466281  https://www.lendingclub.com/browse/loanDetail....
# 466282  https://www.lendingclub.com/browse/loanDetail....
# 466283  https://www.lendingclub.com/browse/loanDetail....
# 466284  https://www.lendingclub.com/browse/loanDetail....
#
#                                                      desc             purpose  \
# 0         Borrower added on 12/22/11 > I need to upgra...         credit_card
# 1         Borrower added on 12/22/11 > I plan to use t...                 car
# 2                                                     NaN      small_business
# 3         Borrower added on 12/21/11 > to pay for prop...               other
# 4         Borrower added on 12/21/11 > I plan on combi...               other
# ...                                                   ...                 ...
# 466280                                                NaN  debt_consolidation
# 466281                                                NaN  debt_consolidation
# 466282    Borrower added on 12/06/13 > I am going to c...  debt_consolidation
# 466283                                                NaN         credit_card
# 466284    Borrower added on 12/04/13 > I will like a l...               other
#
#                           title zip_code addr_state initial_list_status  \
# 0                      Computer    860xx         AZ                   f
# 1                          bike    309xx         GA                   f
# 2          real estate business    606xx         IL                   f
# 3                      personel    917xx         CA                   f
# 4                      Personal    972xx         OR                   f
# ...                         ...      ...        ...                 ...
# 466280       Debt consolidation    773xx         TX                   w
# 466281       Debt consolidation    377xx         TN                   f
# 466282       Debt consolidation    458xx         OH                   f
# 466283  Credit card refinancing    913xx         CA                   w
# 466284                    Other    950xx         CA                   f
#
#        application_type
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2            INDIVIDUAL
# 3            INDIVIDUAL
# 4            INDIVIDUAL
# ...                 ...
# 466280       INDIVIDUAL
# 466281       INDIVIDUAL
# 466282       INDIVIDUAL
# 466283       INDIVIDUAL
# 466284       INDIVIDUAL
#
# [466285 rows x 17 columns]

# %%
for kolom in object_col:
    print(df_copy[kolom].value_counts())
    print()
# Out:
# term
#  36 months    337953
#  60 months    128332
# Name: count, dtype: int64
#
# grade
# B    136929
# C    125293
# D     76888
# A     74867
# E     35757
# F     13229
# G      3322
# Name: count, dtype: int64
#
# sub_grade
# B3    31686
# B4    30505
# C1    26953
# C2    26740
# B2    26610
# C3    25317
# B5    25252
# C4    24105
# B1    22876
# C5    22178
# A5    21757
# D1    19261
# A4    19045
# D2    17046
# D3    14916
# D4    14099
# A3    12568
# D5    11566
# A2    10956
# A1    10541
# E1     9033
# E2     8669
# E3     6976
# E4     5992
# E5     5087
# F1     3940
# F2     3001
# F3     2708
# F4     2067
# F5     1513
# G1     1109
# G2      823
# G3      583
# G4      422
# G5      385
# Name: count, dtype: int64
#
# emp_title
# Teacher                              5399
# Manager                              4438
# Registered Nurse                     2316
# RN                                   2204
# Supervisor                           1967
#                                      ...
# The Eastern Arizona AHEC                1
# Delaware Quarries.com                   1
# McCauley trucking and warehousing       1
# save mart supermarkets                  1
# Server Engineer Lead                    1
# Name: count, Length: 205475, dtype: int64
#
# emp_length
# 10+ years    150049
# 2 years       41373
# 3 years       36596
# < 1 year      36265
# 5 years       30774
# 1 year        29622
# 4 years       28023
# 7 years       26180
# 6 years       26112
# 8 years       22395
# 9 years       17888
# Name: count, dtype: int64
#
# home_ownership
# MORTGAGE    235875
# RENT        188473
# OWN          41704
# OTHER          182
# NONE            50
# ANY              1
# Name: count, dtype: int64
#
# verification_status
# Verified           168055
# Source Verified    149993
# Not Verified       148237
# Name: count, dtype: int64
#
# loan_status
# Current                                                224226
# Fully Paid                                             184739
# Charged Off                                             42475
# Late (31-120 days)                                       6900
# In Grace Period                                          3146
# Does not meet the credit policy. Status:Fully Paid       1988
# Late (16-30 days)                                        1218
# Default                                                   832
# Does not meet the credit policy. Status:Charged Off       761
# Name: count, dtype: int64
#
# pymnt_plan
# n    466276
# y         9
# Name: count, dtype: int64
#
# url
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=1077501     1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=26180404    1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=26219322    1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=26239577    1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=26290537    1
#                                                                         ..
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=3714715     1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=3703738     1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=3731030     1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=3705772     1
# https://www.lendingclub.com/browse/loanDetail.action?loan_id=9199665     1
# Name: count, Length: 466285, dtype: int64
#
# desc
#                                                                                                                                                                                                                                                  234
# Debt Consolidation                                                                                                                                                                                                                                13
#   Borrower added on 03/17/14 > Debt consolidation<br>                                                                                                                                                                                             11
#   Borrower added on 03/10/14 > Debt consolidation<br>                                                                                                                                                                                             10
#   Borrower added on 02/19/14 > Debt consolidation<br>                                                                                                                                                                                              9
#                                                                                                                                                                                                                                                 ...
#   Borrower added on 09/24/13 > Credit debt<br>                                                                                                                                                                                                     1
#   Borrower added on 09/24/13 > wish to consolidate loans<br>                                                                                                                                                                                       1
#   Borrower added on 09/24/13 > To payoff credit card debt<br>                                                                                                                                                                                      1
#   Borrower added on 09/24/13 > To consolidate my debt by paying of my mortgage which is 278 a month my car payment which is 278 a month and 2 credit cards  which total 1800. By doing this I would free up an extra 200 dollars a month.<br>      1
#   Borrower added on 12/04/13 > I will like a loan to fix  our cars and paid our house property tax<br>                                                                                                                                             1
# Name: count, Length: 124435, dtype: int64
#
# purpose
# debt_consolidation    274195
# credit_card           104157
# home_improvement       26537
# other                  23690
# major_purchase          9828
# small_business          7013
# car                     5397
# medical                 4602
# moving                  2994
# vacation                2487
# wedding                 2343
# house                   2269
# educational              422
# renewable_energy         351
# Name: count, dtype: int64
#
# title
# Debt consolidation                   164075
# Credit card refinancing               62275
# Debt Consolidation                    15760
# Home improvement                      14849
# Other                                 12713
#                                       ...
# Windows and Siding                        1
# Credit Card Clearance                     1
# credit repayment                          1
# medical bills/credit card payoff          1
# Paying off the car and some bills         1
# Name: count, Length: 63098, dtype: int64
#
# zip_code
# 945xx    5304
# 112xx    5102
# 750xx    5013
# 606xx    4696
# 100xx    4391
#          ...
# 204xx       1
# 502xx       1
# 514xx       1
# 049xx       1
# 901xx       1
# Name: count, Length: 888, dtype: int64
#
# addr_state
# CA    71450
# NY    40242
# TX    36439
# FL    31637
# IL    18612
# NJ    18061
# PA    16424
# OH    15237
# GA    14975
# VA    14222
# NC    12682
# MI    11549
# MA    11072
# MD    10974
# AZ    10712
# WA    10517
# CO     9739
# MN     8158
# MO     7508
# CT     7204
# IN     6525
# NV     6519
# TN     5984
# OR     5949
# WI     5911
# AL     5853
# SC     5583
# LA     5489
# KY     4438
# KS     4190
# OK     4117
# AR     3488
# UT     3428
# NM     2588
# HI     2487
# WV     2412
# NH     2232
# RI     2050
# DC     1426
# MT     1396
# DE     1272
# AK     1251
# MS     1226
# WY     1128
# SD      980
# VT      905
# IA       14
# NE       14
# ID       12
# ME        4
# Name: count, dtype: int64
#
# initial_list_status
# f    303005
# w    163280
# Name: count, dtype: int64
#
# application_type
# INDIVIDUAL    466285
# Name: count, dtype: int64

# %%
array_col_object = []

for kolom in object_col:
    array_col_object.append([kolom, df_copy[kolom].nunique(), df[kolom].unique()[:4]])
    
desc_df = pd.DataFrame(data=array_col_object, columns=['Feature', 'Total Unique Element', 'Unique Sample'])
desc_df
# Out:
#                 Feature  Total Unique Element  \
# 0                  term                     2
# 1                 grade                     7
# 2             sub_grade                    35
# 3             emp_title                205475
# 4            emp_length                    11
# 5        home_ownership                     6
# 6   verification_status                     3
# 7           loan_status                     9
# 8            pymnt_plan                     2
# 9                   url                466285
# 10                 desc                124435
# 11              purpose                    14
# 12                title                 63098
# 13             zip_code                   888
# 14           addr_state                    50
# 15  initial_list_status                     2
# 16     application_type                     1
#
#                                         Unique Sample
# 0                            [ 36 months,  60 months]
# 1                                        [B, C, A, E]
# 2                                    [B2, C4, C5, C1]
# 3   [nan, Ryder, AIR RESOURCES BOARD, University M...
# 4              [10+ years, < 1 year, 1 year, 3 years]
# 5                        [RENT, OWN, MORTGAGE, OTHER]
# 6           [Verified, Source Verified, Not Verified]
# 7         [Fully Paid, Charged Off, Current, Default]
# 8                                              [n, y]
# 9   [https://www.lendingclub.com/browse/loanDetail...
# 10  [  Borrower added on 12/22/11 > I need to upgr...
# 11          [credit_card, car, small_business, other]
# 12   [Computer, bike, real estate business, personel]
# 13                       [860xx, 309xx, 606xx, 917xx]
# 14                                   [AZ, GA, IL, CA]
# 15                                             [f, w]
# 16                                       [INDIVIDUAL]

# %%
# menetapkan nilai unik bahwa fitur bisa sebagai kategori adalah jika nilai uniknya berjumlah 50 dan tidak lebih
# mencari yang tidak bisa dijadikan kategori

not_categorized = []

for kolom in object_col:
    if df_copy[kolom].nunique()>50 or df_copy[kolom].nunique()==1:
        not_categorized.append(kolom)

not_categorized
# Out:
# ['emp_title', 'url', 'desc', 'title', 'zip_code', 'application_type']

# %%
categorized = []

for kolom in object_col:
    if df_copy[kolom].nunique()<=50 and df_copy[kolom].nunique()!=1:
        categorized.append(kolom)

categorized
# Out:
# ['term',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'home_ownership',
#  'verification_status',
#  'loan_status',
#  'pymnt_plan',
#  'purpose',
#  'addr_state',
#  'initial_list_status']

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# #### Catatan I
#
# Saat melihat total nilai unique pada tiap kolom `object`, terdapat beberapa kolom yang nilai uniknya sampai dengan ribuan atau hanya punya satu nilai unik. Hal ini tentu tidak bisa menjadi kategori yang akan dipakai karena himpunan nilainya terlalu banyak. atau tidak cukup (hanya satu nilai). Beberapa kolom yang tidak bisa menjadi data kategori adalah sebagai berikut.
#
# 1. `emp_title` (bisa dilakukan dilihat 20 pekerjaan terbanyak yang menggunakan jasa kemudian dihilangkan)
# 2. `url` (bisa dihilangkan)
# 3. `zip_code` (bisa dihilangkan)
# 4. `desc` (bisa dihilangkan)
# 5. `title` (bisa dilihat 20 title/judul untuk peminjamannya apa kemudian dihilangkan)
# 6. `application_type` (bisa dihilangkan)
#
# Kemudian, fitur dengan tipe data object di bawah dapat dijadikan acuan dalam melakukan kategorisasi.
# 1. `term` (ordinal)
# 2. `grade` (ordinal)
# 3. `sub_grade` (ordinal)
# 4. `emp_length` (ordinal)
# 5. `home_ownership` (nominal)
# 6. `verification_status` (ordinal)
# 7. `loan_status` (ordinal)
# 8. `pymnt_plan` (nominal)
# 9. `purpose` (nominal)
# 10. `addr_state` (nominal)
# 11. `initial_list_status` (nominal)
#
# Dari kedua kelompok tersebut, akan diperlihatkan missing values dari kelompok tipe objek ini.

# %%
def get_data_obj(df:pd.DataFrame):
    list_obj = []
    
    for col in df.columns:
        if df[col].dtypes == "object":
            list_obj.append([col, df[col].isna().sum(), round(100*df[col].isna().sum()/df.shape[0], 2)])
    
    desc_df = pd.DataFrame(data=list_obj, columns=['Feature','Total Null in Feature', 'Null Percentage'])
    return desc_df

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

get_data_obj(df_copy)
# Out:
#                 Feature  Total Null in Feature  Null Percentage
# 0                  term                      0             0.00
# 1                 grade                      0             0.00
# 2             sub_grade                      0             0.00
# 3             emp_title                  27588             5.92
# 4            emp_length                  21008             4.51
# 5        home_ownership                      0             0.00
# 6   verification_status                      0             0.00
# 7           loan_status                      0             0.00
# 8            pymnt_plan                      0             0.00
# 9                   url                      0             0.00
# 10                 desc                 340304            72.98
# 11              purpose                      0             0.00
# 12                title                     21             0.00
# 13             zip_code                      0             0.00
# 14           addr_state                      0             0.00
# 15  initial_list_status                      0             0.00
# 16     application_type                      0             0.00

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
#
# #### Catatan II
#
# Kolom `desc` ternyata mempunyai missing value yang besar. Sedangkan, untuk semua data yang bisa digolongkan sebagai kategori, dapat dikatakan bahwa tingkatan missing value-nya aman dan dapat dilakukan imputasi/pengisian ke beberapa kolom. Fitur kategori yang mempunyai banyak missing value adalah `emp_length` yang mana sebanyak 21008 nilai atau 4.51% data hilang dari fitur tersebut. Selanjutnya, data yang bisa menjadi kategori akan diubah tipe datanya ke dalam tipe kategori.

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
# ##### Ordinal

# %%
# grade
temp_grade = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
df_copy['grade'] = pd.Categorical(df_copy['grade'], categories=temp_grade, ordered=True)

# %%
# sub_grade
temp_sub = ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
       'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
       'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
       'G4', 'G5']
df_copy['sub_grade'] = pd.Categorical(df_copy['sub_grade'], categories=temp_sub, ordered=True)

# %%
# emp_length
length = ['< 1 year','1 year', '2 years', '3 years', '4 years', '5 years', '6 years', '7 years', '8 years', '9 years', '10+ years']
df_copy['emp_length'] = pd.Categorical(df_copy['emp_length'], categories=length, ordered=True)

# %%
# term
df_copy['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
# terdapat spasi pada kolom term, terlebih dahulu dihapus
# bisa menggunakan strip, replace, dan mungkin regex (jika complicated)
df_copy['term'] = df_copy['term'].str.strip()
df_copy['term'].unique()
# Out:
# array(['36 months', '60 months'], dtype=object)

# %%
# ubah kolom ke kategori
term_temp = ['36 months', '60 months']
df_copy['term'] = pd.Categorical(df_copy['term'], categories=term_temp, ordered=True)

# %%
# verification status
df_copy['verification_status'].unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
verify_temp = ['Verified', 'Source Verified', 'Not Verified']
df_copy['verification_status'] = pd.Categorical(df_copy['verification_status'], categories=verify_temp, ordered=True)

# %%
# loan status
# kategori loan_status bisa dipersempit dan diubah
# memberikan kolom baru untuk pengecilan kategori dan dibuat tipe datanya kategori
df_copy['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current', 'Default',
#        'Late (31-120 days)', 'In Grace Period', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
# melakukan penambahan kolom baru
# kolom baru diubah punya tipe data kategori
good_crit = ['Current', 'Fully Paid', 'Does not meet the credit policy. Status:Fully Paid']
df_copy['loan_category'] = df_copy['loan_status'].apply(lambda x: 'Good' if x in good_crit else 'Bad')

status = ['Good', 'Bad']
df_copy['loan_category'] = pd.Categorical(df_copy['loan_category'], categories=status, ordered=True)

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
#     code{
#         font-size: 15px;
#     }
# </style>
# ##### Nominal

# %%
# langsung
# polanya pengubahannya sama sehingga bisa melakukan looping dalam mengubahnya

nominal_cat = ['home_ownership', 'pymnt_plan', 'purpose', 'addr_state', 'initial_list_status']

for nom_cat in nominal_cat:
    temp_cat = df_copy[nom_cat].unique()
    df_copy[nom_cat] = pd.Categorical(df_copy[nom_cat], categories=temp_cat)

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# #### Summary for `df_copy`
# Di bawah ini akan diperlihatkan summary pada `df_copy` dengan `df_copy.info()`

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  category
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  category
#  10  sub_grade                    466285 non-null  category
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  category
#  13  home_ownership               466285 non-null  category
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  category
#  16  issue_d                      466285 non-null  datetime64[ns]
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  category
#  19  url                          466285 non-null  object
#  20  desc                         125981 non-null  object
#  21  purpose                      466285 non-null  category
#  22  title                        466264 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  category
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  datetime64[ns]
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  category
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  datetime64[ns]
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  datetime64[ns]
#  49  last_credit_pull_d           466243 non-null  datetime64[ns]
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
#  75  loan_category                466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(46), int64(7), object(7)
# memory usage: 236.1+ MB

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ## EDA sebelum Dropping
# EDA akan dilakukan untuk fitur-fitur yang kemungkinan akan disisihkan selanjutnya berdasarkan missing value atau kepentingan saat EDA sesudah datanya bersih.

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ### Data Copy from `df_copy`

# %%
df_1 = df_copy.copy()
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  category
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  category
#  10  sub_grade                    466285 non-null  category
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  category
#  13  home_ownership               466285 non-null  category
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  category
#  16  issue_d                      466285 non-null  datetime64[ns]
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  category
#  19  url                          466285 non-null  object
#  20  desc                         125981 non-null  object
#  21  purpose                      466285 non-null  category
#  22  title                        466264 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  category
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  datetime64[ns]
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  category
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  datetime64[ns]
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  datetime64[ns]
#  49  last_credit_pull_d           466243 non-null  datetime64[ns]
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
#  75  loan_category                466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(46), int64(7), object(7)
# memory usage: 236.1+ MB

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# #### Data Object
# Data object yang masih berada pada data akan dilakukan statistika univariat. Tidak semua fitur yang akan dilihat analisis multivariatnya. Bagian ini akan memperlihatkan bagaimana distribusi data dari `title` dan `emp_title`.

# %%
object_feat = []

for kolom in df_1.columns:
    if df_1[kolom].dtype == 'object' and kolom != 'loan_status':
        object_feat.append(kolom)

object_feat
# Out:
# ['emp_title', 'url', 'desc', 'title', 'zip_code', 'application_type']

# %%
df_1[object_feat].describe()
# Out:
#        emp_title                                                url    desc  \
# count     438697                                             466285  125981
# unique    205475                                             466285  124435
# top      Teacher  https://www.lendingclub.com/browse/loanDetail....
# freq        5399                                                  1     234
#
#                      title zip_code application_type
# count               466264   466285           466285
# unique               63098      888                1
# top     Debt consolidation    945xx       INDIVIDUAL
# freq                164075     5304           466285

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ##### `emp_title`

# %%
# semenjak value_counts memunculkannya secara descending
# bisa dilihat 20 value kategori teratas yang mempunayi frekuensi terbanyak
df_1['emp_title'].value_counts().iloc[:20]
# Out:
# emp_title
# Teacher                     5399
# Manager                     4438
# Registered Nurse            2316
# RN                          2204
# Supervisor                  1967
# Project Manager             1624
# Sales                       1624
# Owner                       1527
# Office Manager              1395
# manager                     1312
# Driver                      1296
# General Manager             1263
# Director                    1187
# teacher                     1182
# Engineer                    1049
# driver                       967
# Vice President               944
# President                    915
# owner                        856
# Administrative Assistant     840
# Name: count, dtype: int64

# %%
# penggunaan nama kolom masih banyak yang bercampur
# RN dengan registered nurse adalah nilai yang sama

df_1['emp_title'] = df_1['emp_title'].replace({'RN': 'Registered Nurse'})
df_1['emp_title'] = df_1['emp_title'].str.lower()
df_1['emp_title'].value_counts().iloc[:20]
# Out:
# emp_title
# teacher                     6663
# manager                     6005
# registered nurse            5482
# supervisor                  2857
# owner                       2485
# sales                       2449
# driver                      2352
# project manager             1891
# office manager              1861
# general manager             1694
# truck driver                1472
# director                    1289
# engineer                    1284
# police officer              1123
# president                   1095
# store manager               1076
# vice president              1059
# operations manager          1041
# sales manager               1026
# administrative assistant     971
# Name: count, dtype: int64

# %%
for i in range (0,5):
    print(df['emp_title'].value_counts().iloc[i])
# Out:
# 5399
# 4438
# 2316
# 2204
# 1967

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(y=df_1['emp_title'],
                   palette=['#50876C']*5 + ['#4CAF50']*15,
                   order = df_1['emp_title'].value_counts().iloc[:20].index)
plt.title('Number of Employment Title', fontsize=14)

# Membuat anotasi
# Label untuk bar berdasarkan count dari kategorinya
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), ha='left', va='center')

# Menampilkan plot
plt.show()
# Out:
# C:\Users\Ibrahim Erlangga\AppData\Local\Temp\ipykernel_150956\3048123944.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(y=df_1['emp_title'],

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ##### `title`
# Dilakukan analisis pada kolom `title`. Jika diperhatikan, banyak sekali yang harus diberishkan pada kolom ini untuk mengetahui apa saja judul dari permohonan para peminjam dalam meminjam uang.

# %%
df_1['title'].value_counts().iloc[:100]
# Out:
# title
# Debt consolidation                164075
# Credit card refinancing            62275
# Debt Consolidation                 15760
# Home improvement                   14849
# Other                              12713
# Consolidation                       5381
# debt consolidation                  4834
# Major purchase                      4617
# Debt Consolidation Loan             3804
# Business                            3371
# Medical expenses                    2748
# Credit Card Consolidation           2359
# consolidation                       2174
# Personal Loan                       2133
# Car financing                       2090
# Consolidation Loan                  1778
# Home Improvement                    1772
# Vacation                            1559
# Moving and relocation               1499
# Credit Card Refinance               1467
# Credit Card Payoff                  1386
# Consolidate                         1268
# Personal                            1185
# Loan                                1033
# Home buying                          925
# Freedom                              801
# Credit Card Loan                     783
# personal                             774
# consolidate                          763
# personal loan                        744
# Debt                                 721
# home improvement                     675
# Payoff                               666
# Credit Cards                         652
# payoff                               637
# DEBT CONSOLIDATION                   598
# Debt Consolidation                   595
# Home Improvement Loan                590
# Credit Card                          589
# credit card payoff                   570
# My Loan                              566
# credit card consolidation            507
# credit card refinance                492
# Debt Free                            481
# Small Business Loan                  479
# Refinance                            459
# loan                                 453
# Wedding                              451
# debt                                 445
# Wedding Loan                         444
# Credit Consolidation                 435
# Credit card consolidation            428
# Debt Loan                            426
# consolidation loan                   426
# credit cards                         412
# CC Consolidation                     410
# freedom                              401
# debt consolidation loan              379
# Debt Payoff                          357
# credit card                          349
# Credit card payoff                   347
# Personal loan                        344
# Debt consolidation                   343
# Credit Card Refi                     338
# Debt consolidation loan              335
# Consolidation loan                   330
# Bill Consolidation                   329
# Car Loan                             317
# my loan                              316
# Credit card refinance                315
# debt_consolidation                   313
# Credit Card Debt Consolidation       310
# Medical                              303
# Credit Card Refinancing              301
# debt free                            290
# Loan 1                               282
# Home                                 281
# Credit Card Debt                     278
# Consolidation                        278
# pay off credit cards                 259
# Lending Club                         257
# Credit cards                         253
# Loan Consolidation                   247
# My loan                              246
# Bills                                246
# CC Payoff                            245
# Business Loan                        234
# Lending Club Loan                    231
# pay off                              224
# Other Loan                           220
# debt loan                            215
# Pay off credit cards                 215
# debt consolidation                   213
# Pay Off                              209
# Major Purchase Loan                  204
# Major Purchase                       200
# Pool                                 196
# Credit Card Consolidation Loan       195
# Home Improvements                    195
# Debt Consol                          194
# Name: count, dtype: int64

# %%
df_1['title'] = df_1['title'].str.lower()
df_1['title'].value_counts().iloc[:100]
# Out:
# title
# debt consolidation                185313
# credit card refinancing            62661
# home improvement                   17400
# other                              12799
# consolidation                       7740
# major purchase                      4912
# debt consolidation loan             4683
# credit card consolidation           3509
# business                            3466
# personal loan                       3313
# medical expenses                    2856
# consolidation loan                  2597
# credit card payoff                  2530
# credit card refinance               2437
# car financing                       2116
# consolidate                         2100
# personal                            2021
# vacation                            1747
# loan                                1564
# moving and relocation               1507
# payoff                              1415
# credit cards                        1369
# freedom                             1279
# debt                                1238
# my loan                             1177
# debt consolidation                  1165
# credit card loan                    1125
# credit card                         1113
# debt free                           1028
# home buying                          943
# debt loan                            811
# home improvement loan                756
# pay off credit cards                 740
# debt payoff                          729
# credit consolidation                 676
# refinance                            654
# pay off                              636
# wedding                              613
# credit card refi                     575
# wedding loan                         567
# bill consolidation                   565
# credit card pay off                  562
# credit card debt                     559
# cc consolidation                     555
# small business loan                  518
# car loan                             494
# bills                                469
# home                                 465
# cc payoff                            438
# loan consolidation                   424
# credit card debt consolidation       420
# get out of debt                      407
# medical                              400
# debt relief                          368
# lending club                         367
# debt consol                          366
# consolidation                        362
# loan 1                               358
# wedding expenses                     336
# pay off debt                         333
# home improvements                    333
# business loan                        330
# lending club loan                    327
# consolidate debt                     324
# debt_consolidation                   322
# cc loan                              315
# credit card refinance loan           311
# pool                                 301
# debt consolidate                     292
# cc refinance                         286
# credit                               273
# pool loan                            273
# debt consolodation                   269
# cc refi                              265
# credit card consolidation loan       262
# refi                                 261
# fresh start                          260
# loan1                                256
# debt reduction                       250
# relief                               249
# debit consolidation                  247
# home loan                            246
# freedom loan                         240
# new start                            233
# medical loan                         229
# major purchase loan                  228
# other loan                           226
# moving loan                          219
# help                                 217
# credit refinance                     215
# debt pay off                         209
# pay off bills                        208
# moving                               201
# credit payoff                        196
# refinance loan                       191
# car                                  184
# cards                                184
# home improvement                     184
# debtconsolidation                    181
# credit loan                          181
# Name: count, dtype: int64

# %%
# Konversi kolom 'title' ke tipe data string (jika belum)
df_1['title'] = df_1['title'].astype(str)
result_list = df_1[df_1['title'].str.contains('loan', case=False)]['title'].tolist()
result_list
# Out:
# ['my wedding loan i promise to pay back',
#  'loan',
#  'other loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'credit card repayment loan',
#  'debt consolidation loan',
#  'brown eyes loan',
#  'credit card loan',
#  'december 2011 credit card loan',
#  'debt consolidation loan',
#  'other loan',
#  'small business loan',
#  'other loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'credit card refinance loan',
#  'loan 12142011',
#  'car loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'small_business loan',
#  'refinance loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'small_business loan',
#  'debt consolidation loan',
#  'cc refi loan',
#  'auto loan',
#  'nissan car loan',
#  'car loan',
#  'loan payoff',
#  'emergency loan',
#  'car loan',
#  'major purchase loan',
#  'debt consolidation loan',
#  'credit card loan',
#  "coledon's club loan",
#  'debt consolidation loan',
#  'smaller loan',
#  '12/2011 loan',
#  'credit loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'business loan',
#  'personal loan',
#  'consolidation loan',
#  'credit card loan',
#  'car loan',
#  'auto loan',
#  'consolidation loan',
#  'small business loan',
#  'small business loan',
#  'payoff loan',
#  'loan to pay off credit cards',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'pertsonal loan',
#  '70%attached room,30%cc-loanconsolidation',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'lc loan',
#  'debt consolidation loan',
#  'bank of america pay-off loan',
#  'boat loan',
#  'personnel loan',
#  'vacation loan',
#  'consolidation loan',
#  'loan2011',
#  'car loan',
#  'car loan',
#  'paydown cc loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'personal loan.',
#  'debt consolidation loan',
#  'titanium loan',
#  'credit card and bill loan',
#  'personal loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'personal loan',
#  'trip loan',
#  'loan 1',
#  'debt consolidation loan',
#  'home improvement loan',
#  'car loan and pay off my family',
#  'debt consolidation loan',
#  'home improvement loan',
#  'other loan',
#  'debt consolidation loan',
#  'save the day loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'loan #1',
#  'loan',
#  'home improvement loan',
#  'personal loan',
#  'debt consolidation loan',
#  'debt loan',
#  'debt consolidation loan',
#  'c/c consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'myloan',
#  'debt consolidation loan',
#  'personal loan',
#  'loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'last loan',
#  'my freedom loan',
#  'credit card loan',
#  'short term loan',
#  'debt consolidation loan',
#  'personal loan',
#  'personal loan',
#  'short-term business loan',
#  'personal loan',
#  'renovation loan',
#  'bill loan',
#  'personal investment loan',
#  'debt consolidation loan',
#  'loan 1',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'loan payoff and home improvement',
#  'debt consolidation loan',
#  'pay personal loans',
#  'debt consolidation loan',
#  'consolidation loan december 2011',
#  'credit card loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'my cc consolidation loan',
#  'consolidation loan',
#  'credit card consolodation loan',
#  'wedding planning loan',
#  'loan to fix carpet',
#  'one main loan ',
#  'debt consolidation loan needed!',
#  'end of year loan',
#  'home improvement loan',
#  'credit card loan',
#  'credit_card loan',
#  'consolidation loan',
#  'music production loan',
#  'personal loan',
#  'get out of debt loan',
#  'credit card loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'small_business loan',
#  'debt consolidation loan',
#  'wedding loan',
#  'debt consolidation loan',
#  'debt loan',
#  'debt consolidation loan',
#  'out of debt loan',
#  'small_business loan',
#  'debt consolidation loan',
#  'pay off debt loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit cards consolidation loan',
#  'credit card loan',
#  'car loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit loan consolidation',
#  'personal loan',
#  'other loan',
#  'debt consolidation loan',
#  'small business loan',
#  'salon loan',
#  'alabama consolidation loan',
#  'return customer - 1st loan paid in full',
#  'credit card loan',
#  'credit card refinance loan',
#  'business loan',
#  'small business loan',
#  'other loan',
#  'debt consolidation loan',
#  'vacation loan',
#  'credit card loan',
#  'my loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'credit card payment loans ',
#  'credit card loan',
#  'small business loan',
#  'consolidation loan',
#  'my loan',
#  'debt consolidation loan',
#  'personal business loan',
#  'wedding loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'business loan ',
#  'other loan',
#  'credit card payoff loan',
#  '2011 loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card consolidation loan',
#  'small business loan',
#  'loan #1',
#  'car loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'personal loan',
#  'debt consolidation loan',
#  'business loan',
#  'the blessing loan',
#  'debt consolidation loan',
#  'house loan',
#  'debt consolidation loan',
#  'extra credit loan',
#  'credit card loan',
#  'small business loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'saab 9-3 loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'pay off credit cards loan',
#  'credit card consolidation loan',
#  'debt consolidation loan',
#  'installment loan',
#  'boat loan',
#  'credit card loan',
#  'small business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'loan',
#  'small business loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt consolidation loan',
#  'freedom loan',
#  'personal loan',
#  'debt consolidation loan',
#  'other loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'my loan',
#  'it is really a good loan rate',
#  'debt consolidation loan',
#  'my personal loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'freedom loan',
#  'credit card loan',
#  'payoff loan',
#  'my personl loan',
#  'credit card loan',
#  'credit card loan',
#  'debt loan',
#  'credit card loan',
#  'lendingclubloan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'business loan',
#  'debt consolidation loan',
#  'farm loan',
#  '2011 consolidate loan',
#  'debt consolidation loan',
#  'loan payments',
#  'car loan',
#  'home improvement loan',
#  'credit card loan',
#  'personal loan',
#  'credit card loan',
#  'my loan',
#  'debt loan',
#  'credit card loan',
#  'loan',
#  'credit card refi loan',
#  'credit card consolidation loan',
#  'credit card refinance loan',
#  'credit card loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'other loan',
#  'credit card refinance loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt relief loan',
#  'credit card loan',
#  'dc loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'wedding loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'home improvement / garage loan',
#  'car loan',
#  'personal loan',
#  'person loan ',
#  'credit card loan',
#  'savethedyloan',
#  'home improvement loan',
#  'credit card loan',
#  'credit card loan',
#  'my loan',
#  'credit card loan',
#  'credit card loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt consolidation loan',
#  'other loan',
#  'home improvement loan',
#  'debt loan',
#  'debt consolidation loan',
#  'other loan',
#  'debt consolidation loan',
#  'loan 1',
#  'debt consolidation loan',
#  'personal loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'home improvement loan',
#  'credit card loan',
#  'december 2011 loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'other loan',
#  'loan consolidation',
#  'major purchase loan',
#  'lendingclub debt consolidation loan ',
#  'consolidation loan',
#  'home loan',
#  'loan',
#  'credit card loan',
#  'pool loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt consolidation loan',
#  'moving loan',
#  'credit card loan',
#  'bill consolidation loan',
#  'small business loan',
#  'start up business loans',
#  'small business loan',
#  'pool loan',
#  'personal loan',
#  'loan',
#  'credit card loan',
#  'property investment loan',
#  'hopeful loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt loan',
#  'credit card loan',
#  'credit card loan',
#  'garage door replacement loan',
#  'personal loan',
#  'debt consolidation loan',
#  'small business loan',
#  'used auto loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'home improvment loan',
#  'debt consolidation loan',
#  'my first loan',
#  'credit card and vehicle loan',
#  'invisalign loan',
#  'loan for credit card refinance',
#  'personal loan',
#  'my loan',
#  'credit card loan',
#  'trial loan',
#  'my loan',
#  'personal loan',
#  ' winter loan',
#  'car loan',
#  'personal loan',
#  'freedom loan',
#  'refinance loan',
#  'credit card loan',
#  'major purchase loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'wedding loan',
#  'pay off credit cards and loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'home_improvement loan',
#  'small business loan',
#  'house loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit loan',
#  'home_improvement loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'loan for all debt consolidation',
#  'loan needed',
#  'no risk loan',
#  'personal loan',
#  'business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'medical loan',
#  'debt loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'used car,debt consolidation loan',
#  'vacation loan',
#  'credit card loan',
#  'car loan',
#  'my loan',
#  'loan 1',
#  'bailout loan',
#  'first loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'personal loan',
#  'personal loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'home loan',
#  'credit card consolidation loan',
#  'credit card loan',
#  'my personal loan',
#  'personal loan',
#  'debt consolidation loan',
#  'jeeploan2002',
#  'car loan',
#  'barclay credit card loan',
#  'refinancing loan',
#  'credit card loan',
#  'credit card loan',
#  'personal loan',
#  'small business loan',
#  'credit card loan',
#  'credit card refinance loan',
#  'personal loan',
#  'consolidate loan',
#  'credit card refinance loan 1',
#  'small business loan',
#  'credit card payoff loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'small_business loan',
#  '12/1/11 loan',
#  'credit card loan',
#  'other loan',
#  'debt consolidation loan',
#  'debt loan',
#  "mike's personal loan",
#  'home improvement loan',
#  'credit card loan',
#  'credit cards payment loan',
#  'my lending club loan',
#  'debt consolidation loan',
#  'f350 loan',
#  'personal loan',
#  'cc payoff loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'roof loan',
#  'small_business loan',
#  'loan 9',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'myloan',
#  'debt consolidation loan',
#  'credit_card loan',
#  'e loan',
#  'debt consolidation loan',
#  'wedding loan',
#  'business loan',
#  'credit card loan',
#  'credit card loan',
#  'moving loan',
#  'debt consolidation loan',
#  'my loan',
#  'small_business loan',
#  'debt consolidation loan',
#  'loan to pay  high interest credit cards',
#  'debt consolidation loan',
#  'credit card loan',
#  'other loan',
#  'my loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'wedding loan',
#  'credit card consolidation loan',
#  'small business loan',
#  'debt consolidation loan',
#  'small business loan',
#  'credit card loan',
#  'credit card loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'other loan',
#  'other loan',
#  'debt consolidation loan',
#  'personal loan',
#  'loan',
#  'loan 1',
#  'business loan',
#  'last loan ',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'faster debt reduction loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'last time loan',
#  'debt consolidation loan',
#  'major loan',
#  'small business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'ranger loan',
#  'credit card loan',
#  'loan refi',
#  'home improvement loan',
#  'consolidation loan',
#  'loan consolidation',
#  'loan - home improvement',
#  'loan',
#  'personal loan',
#  'cc loan',
#  'debt consolidation loan',
#  'moving loan',
#  'personal loan ',
#  'personal loan',
#  'get out of debt loan',
#  'personal loan',
#  'home improvement loan',
#  'conso loan',
#  'personal loan',
#  'the blessing loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'to pay off the credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'lending club loan',
#  'major purchase loan',
#  'other loan',
#  'personal loan',
#  'wedding loan',
#  'other loan',
#  'credit card payoff loan',
#  're-do loan',
#  'debt consolidation loan',
#  'home improvement loan',
#  'personal loan',
#  'other loan',
#  'repay loans',
#  'debt consolidation loan',
#  'debt payoff loan',
#  'vwloan',
#  'debt consolidation loan',
#  'combine 2 credit cards into fixed loan',
#  'debt consolidation loan',
#  'small business loan',
#  'home improvement loan',
#  'credit card loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'house loan',
#  'debt consolidation loan',
#  'car loan',
#  'moving loan',
#  'credit card refinance loan',
#  'small business loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'other loan',
#  'loan 1',
#  'small business loan',
#  'debt loan',
#  'my loan',
#  'house loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'car loan',
#  'harley loan',
#  'loan2011',
#  '53 cc debt consolidation loan',
#  'cc payoff loan',
#  'major purchase loan',
#  'car loan',
#  'debt consolidation loan',
#  'prosperity loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'car loan',
#  '2011 loan',
#  'moving loan',
#  'credit card loan',
#  'solar panel loan',
#  'personal loan',
#  'car loan',
#  'debt consolidation loan',
#  'car loan',
#  'debt consolidation loan',
#  'loan 1',
#  'debt consolidation loan',
#  'my loan ',
#  'personal loan',
#  'debt consolidation loan',
#  'christmas loan',
#  'personal loan',
#  'debt consolidation loan',
#  'cadillac loan',
#  'loan-all credit cards',
#  'november loan ',
#  'consolidation loan',
#  'credit card loan',
#  'moving loan',
#  'my loan',
#  'loan consolidation',
#  'loan',
#  'credit card refinance loan',
#  'happier loan consolidation',
#  'consolidation loan',
#  'kitchen loan',
#  'major purchase loan',
#  'other loan',
#  'wedding loan',
#  'home_improvement loan',
#  'credit_card loan',
#  'consolidation loan',
#  'credit card reduction loan',
#  'last loan',
#  'security deposit loan',
#  'debt payoff loan',
#  'loan',
#  'bail me out loan',
#  'personal loan',
#  'loan',
#  'conso loan',
#  'cerdit card & debt loan',
#  'silverloan',
#  'payoff existing loan&debt consoilidation',
#  'home improvement loan',
#  'credit refinancing loan',
#  'moving loan',
#  'credit card payment loan',
#  'fix the debt loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'lendingclub loan',
#  'personal loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'loan consolidation',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'personal loan',
#  'home improvement loan',
#  'loan4me',
#  'business loan',
#  'wedding loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'lending loan',
#  'debt consolidation loan',
#  'credit card payoff loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'major purchase loan',
#  'debt consolidation loan',
#  'major purchase loan',
#  'loan to put property in rental service',
#  'other loan',
#  'lc loan 11/22/11',
#  'other loan',
#  'credit card loan',
#  'get-out-of-debt loan',
#  'personal loan',
#  'major purchase loan',
#  'business loan',
#  'unsecured personal loan',
#  'debt consolidation loan',
#  'major purchase personal loan ',
#  'business growth loan',
#  'other loan',
#  '5 year debt consol loan',
#  'debt consolidation loan',
#  'personal loan',
#  'moving loan',
#  'debt consolidation loan',
#  'car loan',
#  'refinance loan',
#  'debt consolidation loan',
#  'family loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'payoff loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'consalitdating loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'small business loan',
#  'quick loan',
#  'fresh start loan',
#  'auto loan',
#  'debt consolidation loan',
#  'small business loan',
#  'car restoration loan',
#  'personal loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'small business loan',
#  'lc loan',
#  'personal loan',
#  'no debt loan',
#  'debt consolidation loan',
#  'other loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'credit card loan',
#  'card consolidation loan',
#  'debt consolidation loan',
#  'loan20',
#  'consolidation loan',
#  'ring loan',
#  'credit card loan',
#  'personal loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'pay off credit cards loan',
#  'debt consolidation loan',
#  'home improvement loan',
#  'moving loan',
#  'finacial freedom loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'refinance personal loan',
#  'debt consolidation loan',
#  'refinance loan',
#  'debt consolidation loan',
#  'credit card consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'other loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'other loan',
#  'home improvement and car loan pay-off',
#  'wedding loan',
#  'my loan',
#  'loan90',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'loan',
#  'auto loan',
#  'wedding loan',
#  'credit card loan',
#  'business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt consolidation loan',
#  'loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'cc loan',
#  'pay off loan',
#  'personal loan ',
#  'debt consolidation loan',
#  'car loan',
#  'credit card loan',
#  'small business loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'home improvement loan',
#  'debt consolidation loan',
#  'loan1',
#  'credit card loan',
#  'credit card payoff loan',
#  'aid for credit card debt loan',
#  'credit card loan',
#  'student loan and credit card consolidati',
#  'debt loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card &to pay loan',
#  'consolidation loan',
#  'initial loan',
#  'club loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'small business loan',
#  'debt consolidation loan',
#  'my smart loan',
#  'debt consolidation loan',
#  'first loan',
#  'debt consolidation loan',
#  'major purchase loan',
#  'debt consolidation loan',
#  'car loan',
#  'personal loan ',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card payoff loan',
#  'credit card loan',
#  'debt consolidation loan',
#  'family loan',
#  'person loan',
#  'my loan',
#  'debt consolidation loan',
#  'helping me loan',
#  'needed loan',
#  'consolidate loan payment',
#  'debt consolidation loan',
#  'business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'vacation loan',
#  'debt consolidation loan',
#  'small business loan',
#  'credit refinance loan',
#  'small business loan',
#  'debt consolidation loan',
#  'debt repayment loan',
#  'cc loan',
#  'loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'smart loan',
#  'debt consolidation loan',
#  'home improvement loan',
#  'small business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card consolidation loan',
#  'personal property loan',
#  'start up loan',
#  'debt loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'personal loan',
#  'student loan debt consolidation',
#  'small business loan',
#  'debt consolidation loan',
#  'lc loan',
#  'my_loan',
#  'debt consolidation loan',
#  'credit card consolidation loan',
#  'personal loan',
#  ' debt consolidation loan',
#  'personal loan',
#  'credit card loan',
#  'cc loan',
#  'debt consolidation loan',
#  'personal loan',
#  'debt loan',
#  'small business loan',
#  'credit card loan',
#  'cc loan',
#  'cut the credit cards loan',
#  'vaction loan',
#  'moving loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'myloan 2011',
#  'debt consolidation loan',
#  'pay off loan',
#  'debt consolidation loan',
#  'credit card/loan consolidation',
#  'truck loan',
#  'debt consolidation loan',
#  'other loan',
#  'debt consolidation loan',
#  'auto loan with copart',
#  'credit card loan',
#  'other loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'consolidation loan ',
#  'other loan',
#  'small business loan',
#  'debt consolidation loan',
#  'debt consolidation loan',
#  'credit card loan',
#  'credit card consolidation loan',
#  'mikes loan',
#  'consolidation loan ',
#  'personal loan',
#  'debt consolidation loan',
#  'credit card payoff loan',
#  'home improvement loan',
#  ...]

# %%
# mengganti semua string yang bermuatan loan hanya menjadi loan
import re

df_1['title'] = df_1['title'].apply(lambda x: re.sub('.*loan.*', 'loan', str(x), flags=re.IGNORECASE))
df_1['title'].value_counts().iloc[:1000]
# Out:
# title
# debt consolidation                          185313
# credit card refinancing                      62661
# loan                                         39855
# home improvement                             17400
# other                                        12799
# consolidation                                 7740
# major purchase                                4912
# credit card consolidation                     3509
# business                                      3466
# medical expenses                              2856
# credit card payoff                            2530
# credit card refinance                         2437
# car financing                                 2116
# consolidate                                   2100
# personal                                      2021
# vacation                                      1747
# moving and relocation                         1507
# payoff                                        1415
# credit cards                                  1369
# freedom                                       1279
# debt                                          1238
# debt consolidation                            1165
# credit card                                   1113
# debt free                                     1028
# home buying                                    943
# pay off credit cards                           740
# debt payoff                                    729
# credit consolidation                           676
# refinance                                      654
# pay off                                        636
# wedding                                        613
# credit card refi                               575
# bill consolidation                             565
# credit card pay off                            562
# credit card debt                               559
# cc consolidation                               555
# bills                                          469
# home                                           465
# cc payoff                                      438
# credit card debt consolidation                 420
# get out of debt                                407
# medical                                        400
# debt relief                                    368
# lending club                                   367
# debt consol                                    366
# consolidation                                  362
# wedding expenses                               336
# home improvements                              333
# pay off debt                                   333
# consolidate debt                               324
# debt_consolidation                             322
# pool                                           301
# debt consolidate                               292
# cc refinance                                   286
# credit                                         273
# debt consolodation                             269
# cc refi                                        265
# refi                                           261
# fresh start                                    260
# debt reduction                                 250
# relief                                         249
# debit consolidation                            247
# new start                                      233
# help                                           217
# credit refinance                               215
# debt pay off                                   209
# pay off bills                                  208
# moving                                         201
# credit payoff                                  196
# home improvement                               184
# cards                                          184
# car                                            184
# debtconsolidation                              181
# debt                                           178
# dept consolidation                             176
# motorcycle                                     175
# debtfree                                       171
# credit card payment                            170
# card consolidation                             166
# credit card                                    164
# cc                                             161
# back on track                                  159
# card payoff                                    156
# pay off credit card                            154
# financial freedom                              149
# debt cons                                      147
# pay bills                                      147
# out of debt                                    146
# debt con                                       145
# credit card consolidation                      144
# payoff credit cards                            142
# debt freedom                                   140
# credit card repayment                          132
# small business                                 131
# personal                                       127
# consolidate credit cards                       127
# no more credit cards                           126
# house                                          121
# swimming pool                                  120
# taxes                                          114
# credit debt                                    114
# bill payoff                                    112
# improvement                                    112
# debt consilidation                             111
# money                                          110
# lendingclub                                    108
# consol                                         107
# moving expenses                                107
# debt cosolidation                              106
# my debt consolidation                          106
# engagement ring                                104
# debt help                                      102
# paying off credit cards                        101
# consolidate bills                               99
# cc debt                                         98
# mine                                            97
# one payment                                     97
# no more debt                                    96
# payoffs                                         96
# credit card refinance                           96
# bill pay                                        95
# payoff debt                                     95
# new beginning                                   94
# medical bills                                   94
# card refinance                                  93
# pay it off                                      91
# home repair                                     90
# pay credit cards                                89
# credit refi                                     88
# consolidating debt                              88
# consolodation                                   88
# credit card payments                            87
# ccpayoff                                        86
# boat                                            86
# home repairs                                    85
# debt be gone                                    85
# kitchen remodel                                 85
# credit card payoffs                             85
# roof                                            85
# consolidate                                     85
# credit card freedom                             84
# credit card relief                              84
# cc debt consolidation                           83
#  debt consolidation                             81
# car repair                                      81
# refinancing                                     80
# pay off cards                                   80
# consolidated                                    79
# getting out of debt                             79
# credit pay off                                  78
# debtconsol                                      77
# hot tub                                         77
# debt payment                                    76
# debt refinance                                  75
# cc pay off                                      74
# new roof                                        74
# auto                                            73
# debt elimination                                72
# credit cards payoff                             72
# peace of mind                                   72
# investment                                      70
# kitchen                                         69
# credit_card                                     69
# starting over                                   69
# credit card elimination                         68
# credit card pay-off                             68
# discover                                        66
# consolidate credit card debt                    66
# clean slate                                     65
# clean up                                        64
# remodel                                         64
# new beginnings                                  64
# debt repayment                                  64
# home improvment                                 63
# credit debt consolidation                       63
# debt consoldation                               63
# pay off credit card debt                        63
# truck                                           63
# improvements                                    62
# my consolidation                                62
# debts                                           62
# debtcon                                         61
# bill pay off                                    61
# breathing room                                  61
# home down payment                               61
# new life                                        61
# payback                                         60
# creditcardpayoff                                59
# future                                          59
# dc                                              59
# paying off debt                                 58
# debt consoladation                              58
# personal debt consolidation                     58
# business expansion                              57
# credit cards                                    57
# lower interest rate                             57
# relocation                                      57
# debt consolidation 2013                         56
# moving forward                                  56
# credit card reduction                           55
# pay down                                        54
# all in one                                      54
# creditcards                                     54
# purchase                                        54
# debt consolidator                               53
# wedding fund                                    53
# creditcard                                      53
# debt cons.                                      52
# credit card consolidate                         52
# wedding                                         52
# debt consolidation 2012                         52
# card refi                                       51
# ccrefi                                          51
# car repairs                                     50
# consolidating                                   49
# home purchase                                   49
# lower interest                                  49
# getting back on track                           48
# helping hand                                    48
# freedom from debt                               48
# debt buster                                     48
# cc consolidate                                  48
# free                                            48
# payoff bills                                    47
# ring                                            47
# debt consolidation/home improvement             47
# refinance credit cards                          47
# credit cards consolidation                      46
# payoff                                          46
# home                                            46
# free at last                                    46
# debt consildation                               45
# credit refinancing                              45
# repayment                                       45
# thank you                                       44
# getting ahead                                   44
# pay my bills                                    44
# pay debt                                        44
# amex                                            44
# lifesaver                                       43
# freedom                                         43
# pay off                                         43
# credit cards pay off                            43
# home remodel                                    43
# paydown                                         43
# pay off cc                                      43
# christmas                                       43
# refinance credit card                           42
# consolidation of debt                           42
# homeimprovement                                 42
# get rid of debt                                 42
# lower rate                                      41
# dedt consolidation                              41
# expenses                                        41
# credit card paydown                             41
# debt consolidation 1                            40
# consolodate                                     40
# credit card payoff                              40
# life saver                                      40
# pay off debts                                   39
# credit card free                                39
# catch up                                        39
# payment                                         39
# debt consolidation 2                            39
# get out of debt!                                39
# debt conslidation                               39
# pay off high interest credit cards              39
# pay credit card                                 39
# deb consolidation                               38
# down payment                                    38
# debt conso                                      38
# payments                                        38
# card pay off                                    38
# payoff cards                                    38
# credit card debt payoff                         38
# credit                                          38
# home improve                                    37
# bathroom remodel                                37
# consolidating credit cards                      37
# get debt free                                   37
# credit consolidation                            37
# reduce debt                                     37
# second chance                                   36
# working capital                                 36
# credit card consolodation                       36
# debt consalidation                              36
# garage                                          36
# a new start                                     36
# debt free                                       36
# getoutofdebt                                    36
# refinance                                       35
# consolidator                                    35
# school                                          35
# repay                                           35
# debt consolidation and home improvement         35
# bike                                            35
# payoffdebt                                      35
# home inprovement                                34
# consoladation                                   34
# surgery                                         34
# consolidation 2013                              34
# wedding expense                                 34
# creditcard payoff                               34
# debt refi                                       34
# hope                                            33
# 2013 debt consolidation                         33
# credit relief                                   33
# blessing                                        33
# debt eliminator                                 33
# my debt                                         33
# pay-off                                         33
# outofdebt                                       33
# payitoff                                        33
# lending                                         33
# recovery                                        33
# basement                                        33
# cleanup                                         33
# medical expense                                 32
# new kitchen                                     32
# debt management                                 32
# savings                                         32
# a fresh start                                   32
# debt consolidaton                               31
# payoff credit card                              31
# happy                                           31
# atv                                             31
# small_business                                  31
# pay offs                                        31
# debt paydown                                    31
# bathroom                                        31
# education                                       31
# card                                            31
# dental                                          31
# bye bye credit cards                            31
# debt consol.                                    31
# debt  consolidation                             30
# home improvement project                        30
# auto repair                                     30
# cash                                            30
# restructure                                     30
# new car                                         30
# ccdebt                                          30
# consolidation1                                  30
# repairs                                         30
# roof repair                                     29
# 2012 debt consolidation                         29
# emergency                                       29
# debt free plan                                  29
# simplify                                        29
# debtpayoff                                      29
# goodbye credit cards                            29
# credit payment                                  29
# 2013 consolidation                              29
# car payoff                                      29
# consolidate my debt                             29
# debt free in 3                                  29
# credit card refinancing                         29
# get rid of credit cards                         29
# consolidating credit card debt                  29
# final debt consolidation                        29
# windows                                         29
# furniture                                       28
# debt consolitation                              28
# home renovation                                 28
# lower payments                                  28
# amex payoff                                     28
# chase                                           28
# debit                                           28
# spa                                             28
# a new beginning                                 28
# get back on track                               28
# credit card debit                               28
# cc refinancing                                  28
# debt restructure                                28
# restart                                         27
# cosolidation                                    27
# medical                                         27
# credit card refinace                            27
# harley                                          27
# debt free!                                      27
# credit card help                                27
# paying off bills                                27
# debt console                                    27
# debt reducer                                    27
# credit cards gone                               27
# pay off credit                                  27
#  consolidation                                  27
# consolidate cards                               27
# debt refinancing                                27
# renovation                                      26
# new home                                        26
# payoffbills                                     26
# credit card consol                              26
# debt consoildation                              26
# pay off my credit cards                         26
# debt consolidation.                             26
# bill                                            26
# one bill                                        26
# pay of credit cards                             26
# pay off credit cards                            26
# jeep                                            26
# camper                                          26
# business start up                               26
# debt con.                                       25
# consolidating my debt                           25
# paying off credit card debt                     25
# debt gone                                       25
# bill payment                                    25
# pay down debt                                   25
# home_improvement                                25
# major_purchase                                  25
# home addition                                   25
# debt clean up                                   25
# chase payoff                                    25
# newstart                                        25
# 3 year plan                                     25
# consolidated debt                               25
# save money                                      25
# pay it down                                     25
# new                                             25
# home improv                                     25
# 2013                                            25
# me                                              24
# consolidate debts                               24
# pay off high interest credit card               24
# goodbye debt                                    24
# consolidation of credit cards                   24
# bail out                                        24
# high interest debt consolidation                24
# ccc                                             24
# home sweet home                                 24
# debt control                                    24
# high interest credit card consolidation         24
# combine                                         24
# personal consolidation                          24
# freedom from credit cards                       23
# business                                        23
# thanks                                          23
# debt killer                                     23
# no debt                                         23
# paybills                                        23
# pay cards                                       23
# backyard                                        23
# debt payoff                                     23
# first                                           23
# getting it together                             23
# credit reduction                                23
# 2012                                            23
# debtcons                                        23
# deck                                            23
# need help                                       23
# short term                                      23
# life                                            22
# creditcardrefinance                             22
# get out of credit card debt                     22
# dental work                                     22
# debt down                                       22
# consilidation                                   22
# no more credit cards!                           22
# refinancing credit cards                        22
# debt consolidation plan                         22
# becoming debt free                              22
# debt concolidation                              22
# debt fix                                        22
# credit consolidate                              22
# debt payments                                   22
# credit cards refinance                          22
# credit card debt                                22
# debt pay-off                                    22
# 2012 consolidation                              22
# eliminate credit card debt                      22
# refinance credit card debt                      22
# my money                                        22
# creditcardconsolidation                         22
# investment property                             21
# debt considation                                21
# better rate                                     21
# credit card pay down                            21
# credit card killer                              21
# total debt consolidation                        21
# clear debt                                      21
# finance                                         21
# home remodeling                                 21
# nan                                             21
# debt relief                                     21
# debt consolidation load                         21
# vacation                                        21
# starting fresh                                  21
# debt consolidations                             21
# consalidation                                   21
# debt consolation                                21
# paying bills                                    21
# credit card refiance                            21
# debt consolidate                                20
# move                                            20
# stress relief                                   20
# debt consolidation & home improvement           20
# paying off my credit cards                      20
# my future                                       20
# bye bye debt                                    20
# debt free in three                              20
# the payoff                                      20
# payoffcreditcards                               20
# cc consolidation                                20
# no more cards                                   20
# discover payoff                                 20
# tax payment                                     20
# paid off                                        20
# irs                                             20
# home improvement/debt consolidation             20
# pay off my debt                                 20
# payoff cc                                       20
# help me                                         20
# debt free soon                                  20
# basement remodel                                19
# debt1                                           19
# daniel defense                                  19
# roof replacement                                19
# cc repayment                                    19
# conso                                           19
# get ahead                                       19
# home improvement and debt consolidation         19
# cc payment                                      19
# creditcard consolidation                        19
# personal debt                                   19
# consolidation 1                                 19
# rv                                              19
# consolidate 1                                   19
# credit card re-fi                               19
# lending club debt consolidation                 19
# my bills                                        19
# family                                          19
# debt consoliation                               19
# debt solution                                   19
# light at the end of the tunnel                  19
# taking care of business                         19
# ccconsolidation                                 19
# debt consolidation 2011                         19
# paydebt                                         19
# credit card debt reduction                      18
# lower monthly payments                          18
# get it together                                 18
# credit cards be gone                            18
# personal expenses                               18
# one monthly payment                             18
# final consolidation                             18
# debt consolidating                              18
# cc payoffs                                      18
# credit card debts                               18
# creditcardrefi                                  18
# capital one                                     18
# success                                         18
# second                                          18
# consoldation                                    18
# major purchase                                  18
# peace                                           18
# home project                                    18
# 2nd chance                                      18
# main                                            18
# refinance debt                                  18
# consolidate 2013                                18
# bailout                                         18
# equipment purchase                              18
# debit free                                      18
# bill consolidation                              18
# credit card pay off                             18
# vehicle                                         18
# landscaping                                     18
# addition                                        17
# card debt                                       17
# ccrefinance                                     17
# debt removal                                    17
# debt pay                                        17
# consolidation 2                                 17
# wedding ring                                    17
# saving money                                    17
# consolidate credit                              17
# travel                                          17
# business investment                             17
# free from debt                                  17
# piece of mind                                   17
# credit card debt elimination                    17
# no more credit card debt                        17
# credit card cleanup                             17
# helper                                          17
# freshstart                                      17
# motorcycle purchase                             17
# saver                                           17
# bills                                           17
# debt consolidation help                         17
# money saver                                     17
# billpay                                         17
# auto repairs                                    17
# cc consol                                       17
# console                                         17
# refi credit cards                               17
# payoffcc                                        17
# debtconsolidate                                 17
# pay off my bills                                17
# debt consoidation                               17
# fresh start                                     17
# engagement                                      17
# car purchase                                    17
# eliminate debt                                  16
# debt restructuring                              16
# pool                                            16
# dept                                            16
# get rid of credit card debt                     16
# lower debt                                      16
# dept payoff                                     16
# one                                             16
# regroup                                         16
# home free                                       16
# debt away                                       16
# wedding funds                                   16
# get it done                                     16
# credit card clean up                            16
# fence                                           16
# saving                                          16
# unexpected expenses                             16
# credit freedom                                  16
# my help                                         16
# better life                                     16
# paymybills                                      16
# out from under                                  16
# better future                                   16
# salvation                                       16
# trailer                                         16
# american express                                16
# legal fees                                      16
# become debt free                                16
# help me out                                     16
# debt consolidated                               16
# new business                                    16
# new bathroom                                    16
# happiness                                       16
# ccr                                             16
# credit help                                     16
# catching up                                     16
# debit consolidation                             16
# bill payer                                      15
# moving expense                                  15
# eliminate credit cards                          15
# back on my feet                                 15
# refresh                                         15
# my freedom                                      15
# pay it off!                                     15
# lending club                                    15
# catchup                                         15
# dream wedding                                   15
# start over                                      15
# freedom!                                        15
# credit free                                     15
# debt consolid                                   15
# consolidate me                                  15
# path to freedom                                 15
# upgrade                                         15
# rebuild                                         15
# consolidation 2012                              15
# snowball                                        15
# kitchen renovation                              15
# getting debt free                               15
# hvac                                            15
# debtbegone                                      15
# mustang                                         15
# patio                                           15
# home improvements                               15
# get outta debt                                  15
# new begining                                    15
# free of debt                                    15
# bills consolidation                             15
# paying it off                                   15
# happy days                                      15
# credit card debt consolidation                  15
# consolidation plan                              15
# credit card debt free                           15
# pool remodel                                    15
# relief                                          15
# home expenses                                   15
# credit card pay offs                            15
# pay back                                        14
# progress                                        14
# family vacation                                 14
# debt eraser                                     14
# security                                        14
# consolidation of bills                          14
# citi                                            14
# save                                            14
# pay                                             14
# finally                                         14
# debt. consolidation                             14
# debt free goal                                  14
# personal use                                    14
# home imp                                        14
# debt crusher                                    14
# pool repair                                     14
# debt consolidation!                             14
# debtrelief                                      14
# consolidation load                              14
# land purchase                                   14
# visa payoff                                     14
# buying a car                                    14
# home improvments                                14
# free and clear                                  14
# paying off high interest credit cards           14
# high interest credit card payoff                14
# debt cleanup                                    14
# cash flow                                       14
# high interest consolidation                     14
# business startup                                14
# florida                                         14
# debt consolidtion                               14
# get out of debt                                 14
# no credit cards                                 14
# help!                                           14
# credit card consilidation                       14
# getting rid of debt                             14
# fix it                                          14
# get out of debt faster                          14
# no more bills                                   14
# pay my debt                                     14
# lc                                              14
# emergency fund                                  14
# cardpayoff                                      14
# home stuff                                      14
# moving                                          13
# consolidate high interest credit cards          13
# business growth                                 13
# cosolidate                                      13
# taking control                                  13
# pay off all credit cards                        13
# credit repayment                                13
# reconsolidation                                 13
# lesson learned                                  13
# kitchen improvement                             13
# debt pay down                                   13
# bill payments                                   13
# new year                                        13
# paying off credit card                          13
# helpful                                         13
# refiance                                        13
# small debt consolidation                        13
# pay of debt                                     13
# remodeling                                      13
# my wedding                                      13
# cc reduction                                    13
# capital one payoff                              13
# on track                                        13
# cc freedom                                      13
# lower my payments                               13
# dec-12                                          13
# credit fix                                      13
# onepayment                                      13
# pay it all off                                  13
# cc payments                                     13
# cons                                            13
# solution                                        13
# bill consolidate                                13
# new pool                                        13
# refinancing credit card                         13
# golf cart                                       13
# debt consolidatoin                              13
# lower my rate                                   13
# consolidation/home improvement                  13
# free debt                                       13
# credit card bills                               13
# save me                                         13
# needed                                          13
# fresh                                           12
# home upgrades                                   12
# debt saver                                      12
# new beginning                                   12
# interest reduction                              12
# credit cards payments                           12
# payoff credit card debt                         12
# medical debt consolidation                      12
# paying off                                      12
# smart move                                      12
# solar                                           12
# credit card and debt consolidation              12
# goal                                            12
# business capital                                12
# holiday                                         12
# pay the bills                                   12
# family emergency                                12
# car refinance                                   12
# pay debts                                       12
# credit card repay                               12
# debt consolidatio                               12
# lending club consolidation                      12
# reliable                                        12
# no more debt!                                   12
# lower my debt                                   12
# debt be gone!                                   12
# debt fixer                                      12
# 2010                                            12
# work                                            12
# great                                           12
# ccard                                           12
# smart                                           12
# renovations                                     12
# pay my debts                                    12
# debt consolidatin                               12
# consolidate debt                                12
# lower rates                                     12
# consolidate my bills                            12
# credit clean up                                 12
# get free                                        12
# payoff debts                                    12
# renew                                           12
# scooter                                         12
# house repair                                    12
# pay down credit cards                           12
# credit card eliminator                          12
# furnace                                         12
# balance transfer                                12
# debt/credit card consolidation                  12
# lending club 2                                  12
# getting back on my feet                         12
# card consolidate                                12
# repair                                          12
# credit card re-finance                          12
# refinace                                        11
#  debt consolidation                             11
# the pay off                                     11
# payoff credit                                   11
# lower interest rates                            11
# debt conolidation                               11
# backontrack                                     11
# get on track                                    11
# paid in full                                    11
# for me                                          11
# get my life back                                11
# debt condolidation                              11
# card payment                                    11
# debtless                                        11
# consolidate cc debt                             11
# personnal                                       11
# thankful                                        11
# apartment                                       11
# house repairs                                   11
# debt reconsolidation                            11
# amex refinance                                  11
# debit                                           11
# credit card pay                                 11
# stuff                                           11
# pay off high interest rate credit cards         11
# back yard                                       11
# debt reduction                                  11
# dream home                                      11
# blessed                                         11
# air conditioner                                 11
# pay off high interest debt                      11
# legal                                           11
# bmw                                             11
# project                                         11
# personnel                                       11
# opportunity                                     11
# less debt                                       11
# get right                                       11
# boa                                             11
# cc pay                                          11
# my home                                         11
# travel trailer                                  11
# major                                           11
# consolidating                                   11
# lower apr                                       11
# consolidation debt                              11
# creditpayoff                                    11
# credit consol                                   11
# debt-free                                       11
# credit card dept                                11
# pay bill                                        11
# refinance cc                                    11
# going forward                                   11
# road to freedom                                 11
# college                                         11
# cc                                              11
# relocation expenses                             11
# pay bills off                                   11
# a new life                                      11
# credit cards debt                               11
# personel                                        11
# emergency funds                                 11
# dept free                                       11
# used car                                        11
# paying down debt                                11
# payoff high interest credit cards               11
# boat purchase                                   11
# household                                       11
# redemption                                      11
# conslidation                                    11
# consolidation!                                  11
# balance                                         11
# business expenses                               11
# consolidate cc                                  11
# pay them off                                    11
# card payoffs                                    11
# my vacation                                     11
# debt consolitdation                             11
# floors                                          11
# mydebtconsolidation                             11
# debt free future                                11
# first step                                      10
# debt releif                                     10
# consolidating debts                             10
# debt b gone                                     10
# paidoff                                         10
# clean start                                     10
# lifeline                                        10
# pay off debt                                    10
# consildation                                    10
# citibank                                        10
# lending club refinance                          10
# nomoredebt                                      10
# medical bill consolidation                      10
# credit card cons                                10
# deby consolidation                              10
# get me out of debt                              10
# better living                                   10
# bright future                                   10
# new day                                         10
# pay off amex                                    10
# medical bill                                    10
# kitchen upgrade                                 10
# home investment                                 10
# consolid                                        10
# jet ski                                         10
# on the right track                              10
# lending club refi                               10
# private                                         10
# line of credit                                  10
# please help                                     10
# honda                                           10
# my home improvement                             10
# new beginings                                   10
# refi credit card                                10
# complete debt consolidation                     10
# free me                                         10
# daughter's wedding                              10
# stress free                                     10
# chase credit card                               10
# pay of bills                                    10
# house improvement                               10
# clean up debt                                   10
# freedom from credit card debt                   10
# consolidate1                                    10
# debt consolidation and home improvements        10
# car payment                                     10
# nodebt                                          10
# be debt free                                    10
# freedom plan                                    10
# interest rate reduction                         10
# consolidating bills                             10
# lc consolidation                                10
# business purchase                               10
# lower my interest rate                          10
# citicard                                        10
# payoffcards                                     10
# re-finance                                      10
# tuition                                         10
# finish basement                                 10
# land                                            10
# fix                                             10
# re-fi                                           10
# time share                                      10
# payment consolidation                           10
# creditcard refinance                            10
# debt helper                                     10
# pool renovation                                 10
# property                                        10
# new windows                                     10
# debt 1                                          10
# faith                                           10
# bill consol                                     10
# life improvement                                10
# debt consiladation                              10
# set me free                                     10
# equipment                                       10
# homeimprove                                     10
# credit pay                                      10
# debt consoldiation                              10
# honeymoon                                       10
# pay my credit cards                             10
# relief fund                                     10
# business debt consolidation                     10
# helpinghand                                     10
# good bye credit cards                            9
# medical procedure                                9
# consolitation                                    9
# mortgage                                         9
# pay off credit cards!                            9
# discover card payoff                             9
# forward                                          9
# hopeful                                          9
# getting caught up                                9
# sunshine                                         9
# getting married                                  9
# truck payoff                                     9
# one easy payment                                 9
# Name: count, dtype: int64

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# #### Data Numerik
# Sebelum bagian dropping, akan ditetapkan bahwasannya threshold untuk sebuah fitur/kolom yang mempunyai missing value lebih dari 70 persen akan dihapus. Di sini, akan diperlihatkan bagaimana distribusi nilai dari kolom-kolom numerik tersebut.

# %%
# Melihat feature numerik
df_num = df_1.select_dtypes('number')
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   annual_inc                   466281 non-null  float64
#  9   dti                          466285 non-null  float64
#  10  delinq_2yrs                  466256 non-null  float64
#  11  inq_last_6mths               466256 non-null  float64
#  12  mths_since_last_delinq       215934 non-null  float64
#  13  mths_since_last_record       62638 non-null   float64
#  14  open_acc                     466256 non-null  float64
#  15  pub_rec                      466256 non-null  float64
#  16  revol_bal                    466285 non-null  int64
#  17  revol_util                   465945 non-null  float64
#  18  total_acc                    466256 non-null  float64
#  19  out_prncp                    466285 non-null  float64
#  20  out_prncp_inv                466285 non-null  float64
#  21  total_pymnt                  466285 non-null  float64
#  22  total_pymnt_inv              466285 non-null  float64
#  23  total_rec_prncp              466285 non-null  float64
#  24  total_rec_int                466285 non-null  float64
#  25  total_rec_late_fee           466285 non-null  float64
#  26  recoveries                   466285 non-null  float64
#  27  collection_recovery_fee      466285 non-null  float64
#  28  last_pymnt_amnt              466285 non-null  float64
#  29  collections_12_mths_ex_med   466140 non-null  float64
#  30  mths_since_last_major_derog  98974 non-null   float64
#  31  policy_code                  466285 non-null  int64
#  32  annual_inc_joint             0 non-null       float64
#  33  dti_joint                    0 non-null       float64
#  34  verification_status_joint    0 non-null       float64
#  35  acc_now_delinq               466256 non-null  float64
#  36  tot_coll_amt                 396009 non-null  float64
#  37  tot_cur_bal                  396009 non-null  float64
#  38  open_acc_6m                  0 non-null       float64
#  39  open_il_6m                   0 non-null       float64
#  40  open_il_12m                  0 non-null       float64
#  41  open_il_24m                  0 non-null       float64
#  42  mths_since_rcnt_il           0 non-null       float64
#  43  total_bal_il                 0 non-null       float64
#  44  il_util                      0 non-null       float64
#  45  open_rv_12m                  0 non-null       float64
#  46  open_rv_24m                  0 non-null       float64
#  47  max_bal_bc                   0 non-null       float64
#  48  all_util                     0 non-null       float64
#  49  total_rev_hi_lim             396009 non-null  float64
#  50  inq_fi                       0 non-null       float64
#  51  total_cu_tl                  0 non-null       float64
#  52  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(7)
# memory usage: 188.5 MB

# %%
def miss_info(df:pd.DataFrame):
    list_obj = []
    
    for col in df.columns:
        list_obj.append([col, df[col].isna().sum(), round(100*df[col].isna().sum()/df.shape[0], 2)])
    
    desc_df = pd.DataFrame(data=list_obj, columns=['Feature','Total Null in Feature', 'Null Percentage'])
    return desc_df

miss_info(df_num)
# Out:
#                         Feature  Total Null in Feature  Null Percentage
# 0                    Unnamed: 0                      0             0.00
# 1                            id                      0             0.00
# 2                     member_id                      0             0.00
# 3                     loan_amnt                      0             0.00
# 4                   funded_amnt                      0             0.00
# 5               funded_amnt_inv                      0             0.00
# 6                      int_rate                      0             0.00
# 7                   installment                      0             0.00
# 8                    annual_inc                      4             0.00
# 9                           dti                      0             0.00
# 10                  delinq_2yrs                     29             0.01
# 11               inq_last_6mths                     29             0.01
# 12       mths_since_last_delinq                 250351            53.69
# 13       mths_since_last_record                 403647            86.57
# 14                     open_acc                     29             0.01
# 15                      pub_rec                     29             0.01
# 16                    revol_bal                      0             0.00
# 17                   revol_util                    340             0.07
# 18                    total_acc                     29             0.01
# 19                    out_prncp                      0             0.00
# 20                out_prncp_inv                      0             0.00
# 21                  total_pymnt                      0             0.00
# 22              total_pymnt_inv                      0             0.00
# 23              total_rec_prncp                      0             0.00
# 24                total_rec_int                      0             0.00
# 25           total_rec_late_fee                      0             0.00
# 26                   recoveries                      0             0.00
# 27      collection_recovery_fee                      0             0.00
# 28              last_pymnt_amnt                      0             0.00
# 29   collections_12_mths_ex_med                    145             0.03
# 30  mths_since_last_major_derog                 367311            78.77
# 31                  policy_code                      0             0.00
# 32             annual_inc_joint                 466285           100.00
# 33                    dti_joint                 466285           100.00
# 34    verification_status_joint                 466285           100.00
# 35               acc_now_delinq                     29             0.01
# 36                 tot_coll_amt                  70276            15.07
# 37                  tot_cur_bal                  70276            15.07
# 38                  open_acc_6m                 466285           100.00
# 39                   open_il_6m                 466285           100.00
# 40                  open_il_12m                 466285           100.00
# 41                  open_il_24m                 466285           100.00
# 42           mths_since_rcnt_il                 466285           100.00
# 43                 total_bal_il                 466285           100.00
# 44                      il_util                 466285           100.00
# 45                  open_rv_12m                 466285           100.00
# 46                  open_rv_24m                 466285           100.00
# 47                   max_bal_bc                 466285           100.00
# 48                     all_util                 466285           100.00
# 49             total_rev_hi_lim                  70276            15.07
# 50                       inq_fi                 466285           100.00
# 51                  total_cu_tl                 466285           100.00
# 52                 inq_last_12m                 466285           100.00

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ##### Catatan
# Terdapat 3 fitur yang memiliki missing value besar, tetapi tidak 100 persen. Akan diperlihatkan bagaimana distribusi nilai dari fitur-fitur tersebut atau hanya memberikan analisis univariat terhadap fitur-fitur ini. Fitur-fitur yang diberikan adalah sebagai berikut.
#
# 1. `mths_since_last_delinq`
# 2. `mths_since_last_record`
# 3. `mths_since_last_major_derog`
#
# Kemudian, beberapa kolom yang memiliki missing value sekitar 10-20 persen akan dilakukan penghapusan record/baris nantinya. Fitur-fitur tersebut adalah sebagai berikut.
#
# 1. `tot_coll_amt`
# 2. `tot_cur_bal`
# 3. `total_rev_hi_lim`
#
# Untuk kolom yang mempunyai percentage missing value sedikit, akan dilakukan imputasi/pengisian dengan median.

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ##### Visualisasi Distribusi

# %%
df_miss = df_num[['mths_since_last_delinq',
'mths_since_last_record',
'mths_since_last_major_derog'
]]
df_miss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   mths_since_last_delinq       215934 non-null  float64
#  1   mths_since_last_record       62638 non-null   float64
#  2   mths_since_last_major_derog  98974 non-null   float64
# dtypes: float64(3)
# memory usage: 10.7 MB

# %%
miss_col = ['mths_since_last_delinq',
            'mths_since_last_record',
            'mths_since_last_major_derog']

# Tentukan jumlah kolom yang ingin ditampilkan dalam setiap baris
num_columns_per_row = 1

# Hitung jumlah baris yang diperlukan
num_rows = (len(miss_col) + num_columns_per_row - 1) // num_columns_per_row

# Atur ukuran gambar setiap plot sesuai kebutuhan
plt.figure(figsize=(18, 6*num_rows))


for i, col in enumerate (miss_col, 1):

    # Setting bins
    # N tidak disesuaikan dengan dataframe.shape[0]
    # disesuaikan dengan kolomnya
    N = df_num[col].count()
    k = 1 + int(np.log2(N))

    # Plotting
    plt.subplot(num_rows, num_columns_per_row, i)
    sns.histplot(df_num[col], kde=True, color='#A8B1DB', bins=k)
    plt.title(f'{col}')
    plt.xlabel('Nilai Fitur')
    plt.ylabel('Frekuensi')

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ## Dropping and Impute

# %%
df_clean = df_1.copy()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   466285 non-null  int64
#  1   id                           466285 non-null  int64
#  2   member_id                    466285 non-null  int64
#  3   loan_amnt                    466285 non-null  int64
#  4   funded_amnt                  466285 non-null  int64
#  5   funded_amnt_inv              466285 non-null  float64
#  6   term                         466285 non-null  category
#  7   int_rate                     466285 non-null  float64
#  8   installment                  466285 non-null  float64
#  9   grade                        466285 non-null  category
#  10  sub_grade                    466285 non-null  category
#  11  emp_title                    438697 non-null  object
#  12  emp_length                   445277 non-null  category
#  13  home_ownership               466285 non-null  category
#  14  annual_inc                   466281 non-null  float64
#  15  verification_status          466285 non-null  category
#  16  issue_d                      466285 non-null  datetime64[ns]
#  17  loan_status                  466285 non-null  object
#  18  pymnt_plan                   466285 non-null  category
#  19  url                          466285 non-null  object
#  20  desc                         125981 non-null  object
#  21  purpose                      466285 non-null  category
#  22  title                        466285 non-null  object
#  23  zip_code                     466285 non-null  object
#  24  addr_state                   466285 non-null  category
#  25  dti                          466285 non-null  float64
#  26  delinq_2yrs                  466256 non-null  float64
#  27  earliest_cr_line             466256 non-null  datetime64[ns]
#  28  inq_last_6mths               466256 non-null  float64
#  29  mths_since_last_delinq       215934 non-null  float64
#  30  mths_since_last_record       62638 non-null   float64
#  31  open_acc                     466256 non-null  float64
#  32  pub_rec                      466256 non-null  float64
#  33  revol_bal                    466285 non-null  int64
#  34  revol_util                   465945 non-null  float64
#  35  total_acc                    466256 non-null  float64
#  36  initial_list_status          466285 non-null  category
#  37  out_prncp                    466285 non-null  float64
#  38  out_prncp_inv                466285 non-null  float64
#  39  total_pymnt                  466285 non-null  float64
#  40  total_pymnt_inv              466285 non-null  float64
#  41  total_rec_prncp              466285 non-null  float64
#  42  total_rec_int                466285 non-null  float64
#  43  total_rec_late_fee           466285 non-null  float64
#  44  recoveries                   466285 non-null  float64
#  45  collection_recovery_fee      466285 non-null  float64
#  46  last_pymnt_d                 465909 non-null  datetime64[ns]
#  47  last_pymnt_amnt              466285 non-null  float64
#  48  next_pymnt_d                 239071 non-null  datetime64[ns]
#  49  last_credit_pull_d           466243 non-null  datetime64[ns]
#  50  collections_12_mths_ex_med   466140 non-null  float64
#  51  mths_since_last_major_derog  98974 non-null   float64
#  52  policy_code                  466285 non-null  int64
#  53  application_type             466285 non-null  object
#  54  annual_inc_joint             0 non-null       float64
#  55  dti_joint                    0 non-null       float64
#  56  verification_status_joint    0 non-null       float64
#  57  acc_now_delinq               466256 non-null  float64
#  58  tot_coll_amt                 396009 non-null  float64
#  59  tot_cur_bal                  396009 non-null  float64
#  60  open_acc_6m                  0 non-null       float64
#  61  open_il_6m                   0 non-null       float64
#  62  open_il_12m                  0 non-null       float64
#  63  open_il_24m                  0 non-null       float64
#  64  mths_since_rcnt_il           0 non-null       float64
#  65  total_bal_il                 0 non-null       float64
#  66  il_util                      0 non-null       float64
#  67  open_rv_12m                  0 non-null       float64
#  68  open_rv_24m                  0 non-null       float64
#  69  max_bal_bc                   0 non-null       float64
#  70  all_util                     0 non-null       float64
#  71  total_rev_hi_lim             396009 non-null  float64
#  72  inq_fi                       0 non-null       float64
#  73  total_cu_tl                  0 non-null       float64
#  74  inq_last_12m                 0 non-null       float64
#  75  loan_category                466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(46), int64(7), object(7)
# memory usage: 236.1+ MB

# %%
# deleting the numerical with threshold

threshold_percentage = 60


for kolom in df_clean.select_dtypes('number').columns:

    percentage_non_null = (df_clean[kolom].count()/df_clean.shape[0])*100

    if percentage_non_null < threshold_percentage:
        df_clean.drop(kolom, axis=1, inplace=True)

df_clean.select_dtypes('number').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  466285 non-null  int64
#  1   id                          466285 non-null  int64
#  2   member_id                   466285 non-null  int64
#  3   loan_amnt                   466285 non-null  int64
#  4   funded_amnt                 466285 non-null  int64
#  5   funded_amnt_inv             466285 non-null  float64
#  6   int_rate                    466285 non-null  float64
#  7   installment                 466285 non-null  float64
#  8   annual_inc                  466281 non-null  float64
#  9   dti                         466285 non-null  float64
#  10  delinq_2yrs                 466256 non-null  float64
#  11  inq_last_6mths              466256 non-null  float64
#  12  open_acc                    466256 non-null  float64
#  13  pub_rec                     466256 non-null  float64
#  14  revol_bal                   466285 non-null  int64
#  15  revol_util                  465945 non-null  float64
#  16  total_acc                   466256 non-null  float64
#  17  out_prncp                   466285 non-null  float64
#  18  out_prncp_inv               466285 non-null  float64
#  19  total_pymnt                 466285 non-null  float64
#  20  total_pymnt_inv             466285 non-null  float64
#  21  total_rec_prncp             466285 non-null  float64
#  22  total_rec_int               466285 non-null  float64
#  23  total_rec_late_fee          466285 non-null  float64
#  24  recoveries                  466285 non-null  float64
#  25  collection_recovery_fee     466285 non-null  float64
#  26  last_pymnt_amnt             466285 non-null  float64
#  27  collections_12_mths_ex_med  466140 non-null  float64
#  28  policy_code                 466285 non-null  int64
#  29  acc_now_delinq              466256 non-null  float64
#  30  tot_coll_amt                396009 non-null  float64
#  31  tot_cur_bal                 396009 non-null  float64
#  32  total_rev_hi_lim            396009 non-null  float64
# dtypes: float64(26), int64(7)
# memory usage: 117.4 MB

# %%
not_important = [
    'Unnamed: 0',
    'id',
    'member_id',
    'emp_title',
    'url',
    'zip_code',
    'desc',
    'title',
    'application_type',
    'policy_code']

for col in not_important:
    df_clean.drop(col, axis=1, inplace=True)

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   term                        466285 non-null  category
#  4   int_rate                    466285 non-null  float64
#  5   installment                 466285 non-null  float64
#  6   grade                       466285 non-null  category
#  7   sub_grade                   466285 non-null  category
#  8   emp_length                  445277 non-null  category
#  9   home_ownership              466285 non-null  category
#  10  annual_inc                  466281 non-null  float64
#  11  verification_status         466285 non-null  category
#  12  issue_d                     466285 non-null  datetime64[ns]
#  13  loan_status                 466285 non-null  object
#  14  pymnt_plan                  466285 non-null  category
#  15  purpose                     466285 non-null  category
#  16  addr_state                  466285 non-null  category
#  17  dti                         466285 non-null  float64
#  18  delinq_2yrs                 466256 non-null  float64
#  19  earliest_cr_line            466256 non-null  datetime64[ns]
#  20  inq_last_6mths              466256 non-null  float64
#  21  open_acc                    466256 non-null  float64
#  22  pub_rec                     466256 non-null  float64
#  23  revol_bal                   466285 non-null  int64
#  24  revol_util                  465945 non-null  float64
#  25  total_acc                   466256 non-null  float64
#  26  initial_list_status         466285 non-null  category
#  27  out_prncp                   466285 non-null  float64
#  28  out_prncp_inv               466285 non-null  float64
#  29  total_pymnt                 466285 non-null  float64
#  30  total_pymnt_inv             466285 non-null  float64
#  31  total_rec_prncp             466285 non-null  float64
#  32  total_rec_int               466285 non-null  float64
#  33  total_rec_late_fee          466285 non-null  float64
#  34  recoveries                  466285 non-null  float64
#  35  collection_recovery_fee     466285 non-null  float64
#  36  last_pymnt_d                465909 non-null  datetime64[ns]
#  37  last_pymnt_amnt             466285 non-null  float64
#  38  next_pymnt_d                239071 non-null  datetime64[ns]
#  39  last_credit_pull_d          466243 non-null  datetime64[ns]
#  40  collections_12_mths_ex_med  466140 non-null  float64
#  41  acc_now_delinq              466256 non-null  float64
#  42  tot_coll_amt                396009 non-null  float64
#  43  tot_cur_bal                 396009 non-null  float64
#  44  total_rev_hi_lim            396009 non-null  float64
#  45  loan_category               466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(26), int64(3), object(1)
# memory usage: 129.4+ MB

# %%
# filling datetime
# akan menggunakan modus

for col in df_clean.select_dtypes(include='datetime64').columns:
    if df_clean[col].count() < df_clean.shape[0]:
        mode_value = df_clean[col].mode().iloc[0]
        mode_value_datetime = pd.to_datetime(mode_value, errors='coerce')
        df_clean[col].fillna(mode_value_datetime, inplace=True)

# %%
df_clean.select_dtypes(include='datetime64').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   issue_d             466285 non-null  datetime64[ns]
#  1   earliest_cr_line    466285 non-null  datetime64[ns]
#  2   last_pymnt_d        466285 non-null  datetime64[ns]
#  3   next_pymnt_d        466285 non-null  datetime64[ns]
#  4   last_credit_pull_d  466285 non-null  datetime64[ns]
# dtypes: datetime64[ns](5)
# memory usage: 17.8 MB

# %%
# filling category
# menggunakan modus

for col in df_clean.select_dtypes('category').columns:
    if df_clean[col].count() < df_clean.shape[0]:
        mode_cat = df_clean[col].mode().iloc[0]
        df_clean[col].fillna(mode_cat, inplace=True)

df_clean.select_dtypes('category').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   term                 466285 non-null  category
#  1   grade                466285 non-null  category
#  2   sub_grade            466285 non-null  category
#  3   emp_length           466285 non-null  category
#  4   home_ownership       466285 non-null  category
#  5   verification_status  466285 non-null  category
#  6   pymnt_plan           466285 non-null  category
#  7   purpose              466285 non-null  category
#  8   addr_state           466285 non-null  category
#  9   initial_list_status  466285 non-null  category
#  10  loan_category        466285 non-null  category
# dtypes: category(11)
# memory usage: 4.9 MB

# %%
# kolom numerik
# diisi dengan median

for col in df_clean.select_dtypes('number').columns:
    if df_clean[col].count() < df_clean.shape[0]:
        mode_num = df_clean[col].median()
        df_clean[col].fillna(mode_num, inplace=True)

df_clean.select_dtypes('number').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   int_rate                    466285 non-null  float64
#  4   installment                 466285 non-null  float64
#  5   annual_inc                  466285 non-null  float64
#  6   dti                         466285 non-null  float64
#  7   delinq_2yrs                 466285 non-null  float64
#  8   inq_last_6mths              466285 non-null  float64
#  9   open_acc                    466285 non-null  float64
#  10  pub_rec                     466285 non-null  float64
#  11  revol_bal                   466285 non-null  int64
#  12  revol_util                  466285 non-null  float64
#  13  total_acc                   466285 non-null  float64
#  14  out_prncp                   466285 non-null  float64
#  15  out_prncp_inv               466285 non-null  float64
#  16  total_pymnt                 466285 non-null  float64
#  17  total_pymnt_inv             466285 non-null  float64
#  18  total_rec_prncp             466285 non-null  float64
#  19  total_rec_int               466285 non-null  float64
#  20  total_rec_late_fee          466285 non-null  float64
#  21  recoveries                  466285 non-null  float64
#  22  collection_recovery_fee     466285 non-null  float64
#  23  last_pymnt_amnt             466285 non-null  float64
#  24  collections_12_mths_ex_med  466285 non-null  float64
#  25  acc_now_delinq              466285 non-null  float64
#  26  tot_coll_amt                466285 non-null  float64
#  27  tot_cur_bal                 466285 non-null  float64
#  28  total_rev_hi_lim            466285 non-null  float64
# dtypes: float64(26), int64(3)
# memory usage: 103.2 MB

# %%
# drop loan status
df_clean.drop(columns=['loan_status'], axis=1, inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   term                        466285 non-null  category
#  4   int_rate                    466285 non-null  float64
#  5   installment                 466285 non-null  float64
#  6   grade                       466285 non-null  category
#  7   sub_grade                   466285 non-null  category
#  8   emp_length                  466285 non-null  category
#  9   home_ownership              466285 non-null  category
#  10  annual_inc                  466285 non-null  float64
#  11  verification_status         466285 non-null  category
#  12  issue_d                     466285 non-null  datetime64[ns]
#  13  pymnt_plan                  466285 non-null  category
#  14  purpose                     466285 non-null  category
#  15  addr_state                  466285 non-null  category
#  16  dti                         466285 non-null  float64
#  17  delinq_2yrs                 466285 non-null  float64
#  18  earliest_cr_line            466285 non-null  datetime64[ns]
#  19  inq_last_6mths              466285 non-null  float64
#  20  open_acc                    466285 non-null  float64
#  21  pub_rec                     466285 non-null  float64
#  22  revol_bal                   466285 non-null  int64
#  23  revol_util                  466285 non-null  float64
#  24  total_acc                   466285 non-null  float64
#  25  initial_list_status         466285 non-null  category
#  26  out_prncp                   466285 non-null  float64
#  27  out_prncp_inv               466285 non-null  float64
#  28  total_pymnt                 466285 non-null  float64
#  29  total_pymnt_inv             466285 non-null  float64
#  30  total_rec_prncp             466285 non-null  float64
#  31  total_rec_int               466285 non-null  float64
#  32  total_rec_late_fee          466285 non-null  float64
#  33  recoveries                  466285 non-null  float64
#  34  collection_recovery_fee     466285 non-null  float64
#  35  last_pymnt_d                466285 non-null  datetime64[ns]
#  36  last_pymnt_amnt             466285 non-null  float64
#  37  next_pymnt_d                466285 non-null  datetime64[ns]
#  38  last_credit_pull_d          466285 non-null  datetime64[ns]
#  39  collections_12_mths_ex_med  466285 non-null  float64
#  40  acc_now_delinq              466285 non-null  float64
#  41  tot_coll_amt                466285 non-null  float64
#  42  tot_cur_bal                 466285 non-null  float64
#  43  total_rev_hi_lim            466285 non-null  float64
#  44  loan_category               466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(26), int64(3)
# memory usage: 125.9 MB

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ## EDA

# %%
df_cc = df_clean.copy()
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   term                        466285 non-null  category
#  4   int_rate                    466285 non-null  float64
#  5   installment                 466285 non-null  float64
#  6   grade                       466285 non-null  category
#  7   sub_grade                   466285 non-null  category
#  8   emp_length                  466285 non-null  category
#  9   home_ownership              466285 non-null  category
#  10  annual_inc                  466285 non-null  float64
#  11  verification_status         466285 non-null  category
#  12  issue_d                     466285 non-null  datetime64[ns]
#  13  pymnt_plan                  466285 non-null  category
#  14  purpose                     466285 non-null  category
#  15  addr_state                  466285 non-null  category
#  16  dti                         466285 non-null  float64
#  17  delinq_2yrs                 466285 non-null  float64
#  18  earliest_cr_line            466285 non-null  datetime64[ns]
#  19  inq_last_6mths              466285 non-null  float64
#  20  open_acc                    466285 non-null  float64
#  21  pub_rec                     466285 non-null  float64
#  22  revol_bal                   466285 non-null  int64
#  23  revol_util                  466285 non-null  float64
#  24  total_acc                   466285 non-null  float64
#  25  initial_list_status         466285 non-null  category
#  26  out_prncp                   466285 non-null  float64
#  27  out_prncp_inv               466285 non-null  float64
#  28  total_pymnt                 466285 non-null  float64
#  29  total_pymnt_inv             466285 non-null  float64
#  30  total_rec_prncp             466285 non-null  float64
#  31  total_rec_int               466285 non-null  float64
#  32  total_rec_late_fee          466285 non-null  float64
#  33  recoveries                  466285 non-null  float64
#  34  collection_recovery_fee     466285 non-null  float64
#  35  last_pymnt_d                466285 non-null  datetime64[ns]
#  36  last_pymnt_amnt             466285 non-null  float64
#  37  next_pymnt_d                466285 non-null  datetime64[ns]
#  38  last_credit_pull_d          466285 non-null  datetime64[ns]
#  39  collections_12_mths_ex_med  466285 non-null  float64
#  40  acc_now_delinq              466285 non-null  float64
#  41  tot_coll_amt                466285 non-null  float64
#  42  tot_cur_bal                 466285 non-null  float64
#  43  total_rev_hi_lim            466285 non-null  float64
#  44  loan_category               466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(26), int64(3)
# memory usage: 125.9 MB

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ## Categorical Analysis

# %%
df_cc_cat = df_cc.select_dtypes('category')
df_cc_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   term                 466285 non-null  category
#  1   grade                466285 non-null  category
#  2   sub_grade            466285 non-null  category
#  3   emp_length           466285 non-null  category
#  4   home_ownership       466285 non-null  category
#  5   verification_status  466285 non-null  category
#  6   pymnt_plan           466285 non-null  category
#  7   purpose              466285 non-null  category
#  8   addr_state           466285 non-null  category
#  9   initial_list_status  466285 non-null  category
#  10  loan_category        466285 non-null  category
# dtypes: category(11)
# memory usage: 4.9 MB

# %%
# plot

fig, axes = plt.subplots(11,1, figsize=(16,65), squeeze=False)
color_palette = sns.color_palette('pastel', n_colors=len(df_cc_cat.columns))

for i, (col,color) in enumerate(zip(df_cc_cat.columns, color_palette)):
    sns.countplot(x=col, data=df_cc_cat, ax=axes[i, 0], color=color)
    axes[i,0].set_xlabel('')
    axes[i,0].set_ylabel('Frekuensi')
    axes[i,0].set_title(col)

    if i == 7:
        axes[i, 0].set_xticklabels(axes[i, 0].get_xticklabels(), rotation=90, ha='right')
plt.subplots_adjust(hspace=0.8)
plt.show()
# Out:
# C:\Users\Ibrahim Erlangga\AppData\Local\Temp\ipykernel_150956\2951189156.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i, 0].set_xticklabels(axes[i, 0].get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# <style>
#     h1{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 25px;
#     }
#     h2{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 23px;
#     }
#     h3{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 21px;
#     }
#     h4{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     h5{
#         line-height: 15px;
#         margin-bottom: 20px;
#         font-weight: Bold;
#         font-size: 19px;
#     }
#     p{
#         font-size: 15px;
#     }
#     ul{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     ol{
#         line-height: 20px;
#         font-size: 15px;
#         padding-left: 20px;
#     }
#     span{
#         font-size: 15px;
#     }
#     pre{
#         border: 4px solid #ccc;
#         padding: 15px;
#         width: 55%;
#         height: 30%;
#     }
# </style>
# ## Numerical Analysis

# %%
df_cc_num = df_cc.select_dtypes('number')
df_cc_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   funded_amnt                 466285 non-null  int64
#  2   funded_amnt_inv             466285 non-null  float64
#  3   int_rate                    466285 non-null  float64
#  4   installment                 466285 non-null  float64
#  5   annual_inc                  466285 non-null  float64
#  6   dti                         466285 non-null  float64
#  7   delinq_2yrs                 466285 non-null  float64
#  8   inq_last_6mths              466285 non-null  float64
#  9   open_acc                    466285 non-null  float64
#  10  pub_rec                     466285 non-null  float64
#  11  revol_bal                   466285 non-null  int64
#  12  revol_util                  466285 non-null  float64
#  13  total_acc                   466285 non-null  float64
#  14  out_prncp                   466285 non-null  float64
#  15  out_prncp_inv               466285 non-null  float64
#  16  total_pymnt                 466285 non-null  float64
#  17  total_pymnt_inv             466285 non-null  float64
#  18  total_rec_prncp             466285 non-null  float64
#  19  total_rec_int               466285 non-null  float64
#  20  total_rec_late_fee          466285 non-null  float64
#  21  recoveries                  466285 non-null  float64
#  22  collection_recovery_fee     466285 non-null  float64
#  23  last_pymnt_amnt             466285 non-null  float64
#  24  collections_12_mths_ex_med  466285 non-null  float64
#  25  acc_now_delinq              466285 non-null  float64
#  26  tot_coll_amt                466285 non-null  float64
#  27  tot_cur_bal                 466285 non-null  float64
#  28  total_rev_hi_lim            466285 non-null  float64
# dtypes: float64(26), int64(3)
# memory usage: 103.2 MB

# %%
# Count matriks korelasi
corr_matrix = df_cc_num.corr().abs()

# Set Plot Size
plt.figure(figsize=(45, 45))

# Create Heatmap 
sns.heatmap(corr_matrix, annot=True, cmap='Greens', annot_kws={'size': 14})

# Show plot
plt.show()

# %%
high_corr = corr_matrix.where(np.triu(np.ones(corr_matrix.shape, dtype=bool), k=1))
to_drop_corr = [column for column in high_corr.columns if any(high_corr[column] > 0.7)]
to_drop_corr
# Out:
# ['funded_amnt',
#  'funded_amnt_inv',
#  'installment',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'collection_recovery_fee',
#  'last_pymnt_amnt',
#  'total_rev_hi_lim']

# %%
df_cc.drop(to_drop_corr, axis=1, inplace=True)
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   term                        466285 non-null  category
#  2   int_rate                    466285 non-null  float64
#  3   grade                       466285 non-null  category
#  4   sub_grade                   466285 non-null  category
#  5   emp_length                  466285 non-null  category
#  6   home_ownership              466285 non-null  category
#  7   annual_inc                  466285 non-null  float64
#  8   verification_status         466285 non-null  category
#  9   issue_d                     466285 non-null  datetime64[ns]
#  10  pymnt_plan                  466285 non-null  category
#  11  purpose                     466285 non-null  category
#  12  addr_state                  466285 non-null  category
#  13  dti                         466285 non-null  float64
#  14  delinq_2yrs                 466285 non-null  float64
#  15  earliest_cr_line            466285 non-null  datetime64[ns]
#  16  inq_last_6mths              466285 non-null  float64
#  17  open_acc                    466285 non-null  float64
#  18  pub_rec                     466285 non-null  float64
#  19  revol_bal                   466285 non-null  int64
#  20  revol_util                  466285 non-null  float64
#  21  total_acc                   466285 non-null  float64
#  22  initial_list_status         466285 non-null  category
#  23  out_prncp                   466285 non-null  float64
#  24  total_rec_late_fee          466285 non-null  float64
#  25  recoveries                  466285 non-null  float64
#  26  last_pymnt_d                466285 non-null  datetime64[ns]
#  27  next_pymnt_d                466285 non-null  datetime64[ns]
#  28  last_credit_pull_d          466285 non-null  datetime64[ns]
#  29  collections_12_mths_ex_med  466285 non-null  float64
#  30  acc_now_delinq              466285 non-null  float64
#  31  tot_coll_amt                466285 non-null  float64
#  32  tot_cur_bal                 466285 non-null  float64
#  33  loan_category               466285 non-null  category
# dtypes: category(11), datetime64[ns](5), float64(16), int64(2)
# memory usage: 86.7 MB

# %%
df_cc_num.drop(to_drop_corr, axis=1, inplace=True)

# Count matriks korelasi
corr_matrix = df_cc_num.corr().abs()

# Set Plot Size
plt.figure(figsize=(45, 45))

# Create Heatmap 
sns.heatmap(corr_matrix, annot=True, cmap='Blues', annot_kws={'size': 14})

# Show plot
plt.show()

# %%
unused_col = ['pub_rec', 'dti', 'revol_bal', 'total_acc','earliest_cr_line', 'last_credit_pull_d','initial_list_status','tot_coll_amt', 'sub_grade'
,'tot_cur_bal','purpose', 'addr_state', ]
df_cc = df_cc.drop(columns = unused_col)
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   term                        466285 non-null  category
#  2   int_rate                    466285 non-null  float64
#  3   grade                       466285 non-null  category
#  4   emp_length                  466285 non-null  category
#  5   home_ownership              466285 non-null  category
#  6   annual_inc                  466285 non-null  float64
#  7   verification_status         466285 non-null  category
#  8   issue_d                     466285 non-null  datetime64[ns]
#  9   pymnt_plan                  466285 non-null  category
#  10  delinq_2yrs                 466285 non-null  float64
#  11  inq_last_6mths              466285 non-null  float64
#  12  open_acc                    466285 non-null  float64
#  13  revol_util                  466285 non-null  float64
#  14  out_prncp                   466285 non-null  float64
#  15  total_rec_late_fee          466285 non-null  float64
#  16  recoveries                  466285 non-null  float64
#  17  last_pymnt_d                466285 non-null  datetime64[ns]
#  18  next_pymnt_d                466285 non-null  datetime64[ns]
#  19  collections_12_mths_ex_med  466285 non-null  float64
#  20  acc_now_delinq              466285 non-null  float64
#  21  loan_category               466285 non-null  category
# dtypes: category(7), datetime64[ns](3), float64(11), int64(1)
# memory usage: 56.5 MB

# %%
datetime_col = [col for col in df_cc.columns if df_cc[col].dtype == "datetime64[ns]"]
df_cc = df_cc.drop(columns = datetime_col)

# %%
df_cc['term'] = df_cc['term'].str.replace(' months', '')
df_cc['term'] = df_cc['term'].astype(float)

df_cc['emp_length'] = df_cc['emp_length'].str.extract('(\d+)').astype(int)
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   466285 non-null  int64
#  1   term                        466285 non-null  float64
#  2   int_rate                    466285 non-null  float64
#  3   grade                       466285 non-null  category
#  4   emp_length                  466285 non-null  int32
#  5   home_ownership              466285 non-null  category
#  6   annual_inc                  466285 non-null  float64
#  7   verification_status         466285 non-null  category
#  8   pymnt_plan                  466285 non-null  category
#  9   delinq_2yrs                 466285 non-null  float64
#  10  inq_last_6mths              466285 non-null  float64
#  11  open_acc                    466285 non-null  float64
#  12  revol_util                  466285 non-null  float64
#  13  out_prncp                   466285 non-null  float64
#  14  total_rec_late_fee          466285 non-null  float64
#  15  recoveries                  466285 non-null  float64
#  16  collections_12_mths_ex_med  466285 non-null  float64
#  17  acc_now_delinq              466285 non-null  float64
#  18  loan_category               466285 non-null  category
# dtypes: category(5), float64(12), int32(1), int64(1)
# memory usage: 50.3 MB

# %%
encoded_verification = pd.get_dummies(df_cc['verification_status'], prefix='verification', drop_first=True)
encoded_home_ownership = pd.get_dummies(df_cc['home_ownership'], prefix='home', drop_first=True)
encoded_grade = pd.get_dummies(df_cc['grade'], prefix='grade', drop_first=True)

# Combine the encoded features
encoded_categorical = pd.concat([encoded_verification,encoded_home_ownership, encoded_grade], axis=1)
df_cc = pd.concat([df_cc, encoded_categorical], axis=1)

# Drop the original columns
df_cc.drop(['verification_status','home_ownership', 'grade','term','emp_length','pymnt_plan'], axis=1, inplace=True)

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   loan_amnt                     466285 non-null  int64
#  1   int_rate                      466285 non-null  float64
#  2   annual_inc                    466285 non-null  float64
#  3   delinq_2yrs                   466285 non-null  float64
#  4   inq_last_6mths                466285 non-null  float64
#  5   open_acc                      466285 non-null  float64
#  6   revol_util                    466285 non-null  float64
#  7   out_prncp                     466285 non-null  float64
#  8   total_rec_late_fee            466285 non-null  float64
#  9   recoveries                    466285 non-null  float64
#  10  collections_12_mths_ex_med    466285 non-null  float64
#  11  acc_now_delinq                466285 non-null  float64
#  12  loan_category                 466285 non-null  category
#  13  verification_Source Verified  466285 non-null  bool
#  14  verification_Not Verified     466285 non-null  bool
#  15  home_OWN                      466285 non-null  bool
#  16  home_MORTGAGE                 466285 non-null  bool
#  17  home_OTHER                    466285 non-null  bool
#  18  home_NONE                     466285 non-null  bool
#  19  home_ANY                      466285 non-null  bool
#  20  grade_B                       466285 non-null  bool
#  21  grade_C                       466285 non-null  bool
#  22  grade_D                       466285 non-null  bool
#  23  grade_E                       466285 non-null  bool
#  24  grade_F                       466285 non-null  bool
#  25  grade_G                       466285 non-null  bool
# dtypes: bool(13), category(1), float64(11), int64(1)
# memory usage: 48.9 MB

# %%
# Define features (X) and target variable (Y)
X = df_cc.drop('loan_category', axis=1)  # Features
Y = df_cc['loan_category']  # Target variable

# Get the column names as feature names
feature_names = X.columns.tolist()

# %%
# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# Initialize different models
results = {}
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier(),
}

# Initialize dictionary to store classification reports
classification_reports = {}
model_names = []
accuracies = []

# Train and evaluate each model
for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, Y_train)

    print(f"Evaluating {model_name}...")
    Y_pred = model.predict(X_test)

    confusion = confusion_matrix(Y_test, Y_pred)
    classification_rep = classification_report(
        Y_test, Y_pred, target_names=['Good', 'Bad'], zero_division=1  # Handle zero division
    )

    # Store the classification report in the dictionary
    classification_reports[model_name] = classification_rep

    accuracy = accuracy_score(Y_test, Y_pred)

    model_names.append(model_name)
    accuracies.append(accuracy)

    print("\nClassification Report:")
    print(classification_rep)
    print(f"{model_name} Accuracy: {accuracy:.4f}")
    print("=" * 50)
# Out:
# Training Random Forest...
# Evaluating Random Forest...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.97      0.45      0.62     11080
#          Bad       0.93      1.00      0.96     82177
#
#     accuracy                           0.93     93257
#    macro avg       0.95      0.73      0.79     93257
# weighted avg       0.94      0.93      0.92     93257
#
# Random Forest Accuracy: 0.9336
# ==================================================
# Training Logistic Regression...
# Evaluating Logistic Regression...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.98      0.42      0.59     11080
#          Bad       0.93      1.00      0.96     82177
#
#     accuracy                           0.93     93257
#    macro avg       0.95      0.71      0.78     93257
# weighted avg       0.93      0.93      0.92     93257
#
# Logistic Regression Accuracy: 0.9302
# ==================================================
# Training Decision Tree...
# Evaluating Decision Tree...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.48      0.53      0.50     11080
#          Bad       0.94      0.92      0.93     82177
#
#     accuracy                           0.87     93257
#    macro avg       0.71      0.72      0.71     93257
# weighted avg       0.88      0.87      0.88     93257
#
# Decision Tree Accuracy: 0.8749
# ==================================================
# Training Gradient Boosting...
# Evaluating Gradient Boosting...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.99      0.45      0.62     11080
#          Bad       0.93      1.00      0.96     82177
#
#     accuracy                           0.93     93257
#    macro avg       0.96      0.72      0.79     93257
# weighted avg       0.94      0.93      0.92     93257
#
# Gradient Boosting Accuracy: 0.9338
# ==================================================
# Training K-Nearest Neighbors...
# Evaluating K-Nearest Neighbors...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.81      0.36      0.50     11080
#          Bad       0.92      0.99      0.95     82177
#
#     accuracy                           0.91     93257
#    macro avg       0.87      0.67      0.73     93257
# weighted avg       0.91      0.91      0.90     93257
#
# K-Nearest Neighbors Accuracy: 0.9141
# ==================================================

# %%
Xov = df_cc.drop(['loan_category'], axis=1)
yov = df_cc['loan_category']

# %%
oversample = RandomOverSampler(sampling_strategy = 'not majority')
X_over, y_over = oversample.fit_resample(Xov, yov)

# %%
# Split the data into training and testing sets (80% training, 20% testing)
X_train_over, X_test_over, Y_train_over, Y_test_over = train_test_split(X_over, y_over, test_size=0.2, random_state=42)

# %%
# Normalize features
scaler = StandardScaler()
X_train_over = scaler.fit_transform(X_train_over)
X_test_over = scaler.fit_transform(X_test_over)

# %%
# Initialize different models
results = {}
models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier(),
}

# Initialize dictionary to store classification reports
classification_reports = {}
model_names_over = []
accuracies_over = []

# Train and evaluate each model
for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(X_train_over, Y_train_over)

    print(f"Evaluating {model_name}...")
    Y_pred = model.predict(X_test_over)

    confusion = confusion_matrix(Y_test_over, Y_pred)
    classification_rep = classification_report(
        Y_test_over, Y_pred, target_names=['Good', 'Bad'], zero_division=1  # Handle zero division
    )

    # Store the classification report in the dictionary
    classification_reports[model_name] = classification_rep

    accuracy = accuracy_score(Y_test_over, Y_pred)

    model_names_over.append(model_name)
    accuracies_over.append(accuracy)

    print("\nClassification Report:")
    print(classification_rep)
    print(f"{model_name} Accuracy: {accuracy:.4f}")
    print("=" * 50)
# Out:
# Training Random Forest...
# Evaluating Random Forest...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.99      0.96      0.98     81995
#          Bad       0.97      0.99      0.98     82387
#
#     accuracy                           0.98    164382
#    macro avg       0.98      0.98      0.98    164382
# weighted avg       0.98      0.98      0.98    164382
#
# Random Forest Accuracy: 0.9769
# ==================================================
# Training Logistic Regression...
# Evaluating Logistic Regression...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.87      0.60      0.71     81995
#          Bad       0.70      0.91      0.79     82387
#
#     accuracy                           0.76    164382
#    macro avg       0.78      0.75      0.75    164382
# weighted avg       0.78      0.76      0.75    164382
#
# Logistic Regression Accuracy: 0.7552
# ==================================================
# Training Decision Tree...
# Evaluating Decision Tree...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.91      0.84      0.87     81995
#          Bad       0.85      0.91      0.88     82387
#
#     accuracy                           0.88    164382
#    macro avg       0.88      0.88      0.88    164382
# weighted avg       0.88      0.88      0.88    164382
#
# Decision Tree Accuracy: 0.8772
# ==================================================
# Training Gradient Boosting...
# Evaluating Gradient Boosting...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.69      0.80      0.74     81995
#          Bad       0.77      0.64      0.70     82387
#
#     accuracy                           0.72    164382
#    macro avg       0.73      0.72      0.72    164382
# weighted avg       0.73      0.72      0.72    164382
#
# Gradient Boosting Accuracy: 0.7227
# ==================================================
# Training K-Nearest Neighbors...
# Evaluating K-Nearest Neighbors...
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Good       0.81      0.98      0.89     81995
#          Bad       0.97      0.77      0.86     82387
#
#     accuracy                           0.87    164382
#    macro avg       0.89      0.87      0.87    164382
# weighted avg       0.89      0.87      0.87    164382
#
# K-Nearest Neighbors Accuracy: 0.8741
# ==================================================
